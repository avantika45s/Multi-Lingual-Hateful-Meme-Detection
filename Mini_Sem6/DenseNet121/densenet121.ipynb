# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer, BertModel
import re
import glob

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load dataset
df = pd.read_csv('/kaggle/input/multilingual-meme-datasets/final_datasets.csv')
print(f"Dataset loaded with shape: {df.shape}")

# Image directory
image_dir = "/kaggle/input/multilingual-meme-datasets/datasets/datasets"

def create_image_mapping(dataframe, image_directory):
    """
    Create a mapping between dataset 'name' column and actual image filenames in the directory.
    This handles the case where image filenames might have different formats.
    """
    # Get all image files in the directory
    image_files = glob.glob(os.path.join(image_directory, '*'))
    image_mapping = {}
    
    # Create a set of all available image filenames (without path)
    available_images = {os.path.basename(f) for f in image_files}
    print(f"Found {len(available_images)} images in directory")
    
    # Print some sample images to understand the naming pattern
    print("Sample image filenames:", list(available_images)[:5])
    
    # Print some sample names from the dataset
    print("Sample names from dataset:", dataframe['name'].iloc[:5].tolist())
    
    # Method 1: Exact match
    for name in dataframe['name'].unique():
        if name in available_images:
            image_mapping[name] = name
    
    # Method 2: Check if the id is part of the filename
    unmapped_names = set(dataframe['name']) - set(image_mapping.keys())
    for name in unmapped_names:
        # Extract ID from name (assuming name has some ID pattern)
        id_match = re.search(r'\d+', name)
        if id_match:
            id_value = id_match.group()
            # Look for files containing this ID
            matching_files = [f for f in available_images if id_value in f]
            if matching_files:
                image_mapping[name] = matching_files[0]
    
    # Method 3: Try matching using 'ids' or 'id' column if available
    if 'ids' in dataframe.columns or 'id' in dataframe.columns:
        id_col = 'ids' if 'ids' in dataframe.columns else 'id'
        id_to_name = dict(zip(dataframe[id_col], dataframe['name']))
        
        for id_value, name in id_to_name.items():
            if name not in image_mapping:
                # Look for files containing this ID
                matching_files = [f for f in available_images if str(id_value) in f]
                if matching_files:
                    image_mapping[name] = matching_files[0]
    
    print(f"Successfully mapped {len(image_mapping)} out of {len(dataframe['name'].unique())} unique names")
    return image_mapping

# Custom dataset class with image mapping for DenseNet121
class HarmfulContentDataset(Dataset):
    def __init__(self, dataframe, image_dir, tokenizer, image_mapping=None, max_len=128):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.image_mapping = image_mapping or {}
        
        # Create a default blank image to use when an image is not found
        self.blank_image = Image.new('RGB', (224, 224), color='white')
        
        # Image transformation for DenseNet121 (224x224 input size)
        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Text features
        text_features = f"{row['gender']} {row['age']} {row['age_bucket']} {row['dominant_emotion']} {row['dominant_race']} {row['translated_text']}"
        
        # Tokenize text
        encoding = self.tokenizer.encode_plus(
            text_features,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        
        # Image processing
        try:
            # Get the correct image filename using the mapping
            image_filename = self.image_mapping.get(row['name'], row['name'])
            image_path = os.path.join(self.image_dir, image_filename)
            
            # Check if the file exists
            if os.path.exists(image_path):
                image = Image.open(image_path).convert('RGB')
            else:
                # Try alternate approach: check if the file exists with different extensions
                base_name = os.path.splitext(image_path)[0]
                for ext in ['.jpg', '.jpeg', '.png', '.gif']:
                    alt_path = base_name + ext
                    if os.path.exists(alt_path):
                        image = Image.open(alt_path).convert('RGB')
                        break
                else:
                    # If still not found, use blank image
                    image = self.blank_image
                    if idx % 100 == 0:  # Limit logging to avoid flooding
                        print(f"Image not found for {row['name']}, using blank image")
            
            # Apply transformations for DenseNet121
            image_tensor = self.transform(image)
            
        except Exception as e:
            if idx % 100 == 0:  # Limit logging
                print(f"Error processing image for {row['name']}: {e}")
            # Create blank image features
            image_tensor = torch.zeros((3, 224, 224))
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'image': image_tensor,
            'labels': torch.tensor(row['label'], dtype=torch.long)
        }

# Custom model class using DenseNet121 + BERT
class DenseNet121BertClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(DenseNet121BertClassifier, self).__init__()
        
        # Load pretrained DenseNet121
        self.densenet = models.densenet121(pretrained=True)
        
        # Remove the classification layer
        self.densenet.classifier = nn.Identity()
        
        # Load pre-trained BERT
        self.bert = BertModel.from_pretrained("bert-base-multilingual-cased")
        
        # Freeze DenseNet weights
        for param in self.densenet.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of DenseNet
        # Unfreeze the last denseblock and transition layer
        for param in self.densenet.features.denseblock4.parameters():
            param.requires_grad = True
        for param in self.densenet.features.transition3.parameters():
            param.requires_grad = True
        
        # Freeze BERT weights
        for param in self.bert.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of BERT
        for param in self.bert.encoder.layer[-2:].parameters():
            param.requires_grad = True
        
        # Dimensionality of DenseNet and BERT embeddings
        densenet_hidden_size = 1024  # DenseNet121 output feature size
        bert_hidden_size = self.bert.config.hidden_size  # 768 for BERT base
        
        # Enhanced classification head
        self.classifier = nn.Sequential(
            nn.Linear(densenet_hidden_size + bert_hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
        
    def forward(self, input_ids, attention_mask, image):
        # Process image with DenseNet121
        image_features = self.densenet.features(image)
        image_features = nn.functional.adaptive_avg_pool2d(image_features, (1, 1))
        image_features = image_features.view(image_features.size(0), -1)  # Flatten the features
        
        # Process text with BERT
        bert_outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        bert_embeddings = bert_outputs.last_hidden_state[:, 0, :]  # CLS token
        
        # Concatenate image and text features
        combined_embeddings = torch.cat((image_features, bert_embeddings), dim=1)
        
        # Classification
        logits = self.classifier(combined_embeddings)
        
        return logits

# Training function
def train_model(model, train_loader, valid_loader, criterion, optimizer, scheduler=None, num_epochs=10):
    train_losses = []
    valid_losses = []
    train_accuracies = []
    valid_accuracies = []
    
    best_valid_loss = float('inf')
    
    for epoch in range(num_epochs):
        # Training
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for batch_idx, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            optimizer.zero_grad()
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            
            # Print batch progress
            if (batch_idx + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
        
        train_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        
        # Validation
        model.eval()
        running_valid_loss = 0.0
        correct_valid = 0
        total_valid = 0
        
        with torch.no_grad():
            for batch in valid_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                images = batch['image'].to(device)
                labels = batch['labels'].to(device)
                
                outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
                loss = criterion(outputs, labels)
                
                running_valid_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total_valid += labels.size(0)
                correct_valid += (predicted == labels).sum().item()
        
        valid_loss = running_valid_loss / len(valid_loader)
        valid_accuracy = correct_valid / total_valid
        valid_losses.append(valid_loss)
        valid_accuracies.append(valid_accuracy)
        
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, '
              f'Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_accuracy:.4f}')
        
        # Update scheduler if provided
        if scheduler is not None:
            scheduler.step(valid_loss)
        
        # Save best model
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), 'best_densenet_bert_model.pth')
            print(f'Saved model with validation loss: {valid_loss:.4f}')
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Function for evaluation and metrics
def evaluate_model(model, test_loader):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            _, predicted = torch.max(outputs.data, 1)
            
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    conf_matrix = confusion_matrix(y_true, y_pred)
    class_report = classification_report(y_true, y_pred, target_names=['Non-Harmful', 'Harmful'])
    
    print(f'Test Accuracy: {accuracy:.4f}')
    print('\nConfusion Matrix:')
    print(conf_matrix)
    print('\nClassification Report:')
    print(class_report)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Harmful', 'Harmful'], 
                yticklabels=['Non-Harmful', 'Harmful'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig('densenet_confusion_matrix.png')
    plt.show()
    
    return accuracy, conf_matrix, class_report

# Function to plot training curves
def plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies):
    # Plot loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(valid_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('densenet_training_curves.png')
    plt.show()

# Helper function to inspect dataset
def inspect_dataset(df, image_dir):
    """
    Inspects the dataset and the image directory to understand the structure.
    """
    print("\n=== Dataset Inspection ===")
    print(f"Dataset columns: {df.columns.tolist()}")
    print(f"Number of rows: {len(df)}")
    print(f"Label distribution: {df['label'].value_counts().to_dict()}")
    
    # Check if image directory exists
    if not os.path.exists(image_dir):
        print(f"WARNING: Image directory does not exist: {image_dir}")
        return
    
    # Count image files
    image_files = [f for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f)) and 
                   f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
    
    print(f"Number of image files in directory: {len(image_files)}")
    if len(image_files) > 0:
        print(f"Sample image filenames: {image_files[:5]}")
    
    # Check name column format
    print("\nSample names from dataset:")
    print(df['name'].head(5).tolist())
    
    # Check if any dataset names exactly match image filenames
    matching_names = [name for name in df['name'].unique() if name in image_files]
    print(f"Number of exact matches between 'name' column and image filenames: {len(matching_names)}")
    
    # Check if IDs are in the name column
    if 'id' in df.columns or 'ids' in df.columns:
        id_col = 'ids' if 'ids' in df.columns else 'id'
        print(f"\nSample values from '{id_col}' column:")
        print(df[id_col].head(5).tolist())
        
        # Check if IDs are in image filenames
        sample_ids = df[id_col].astype(str).head(5).tolist()
        for id_val in sample_ids:
            matches = [f for f in image_files if id_val in f]
            if matches:
                print(f"Found matches for ID {id_val}: {matches[:2]}")
                
    return image_files

# Main execution
def main():
    # Initialize tokenizer for BERT
    tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
    
    # Inspect dataset and image directory
    image_files = inspect_dataset(df, image_dir)
    
    # Create mapping between dataset names and image filenames
    image_mapping = create_image_mapping(df, image_dir)
    
    # Split dataset
    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, stratify=df['label'])
    valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['label'])
    
    print(f"Train set: {len(train_df)}, Validation set: {len(valid_df)}, Test set: {len(test_df)}")
    
    # Create datasets with image mapping
    train_dataset = HarmfulContentDataset(train_df, image_dir, tokenizer, image_mapping)
    valid_dataset = HarmfulContentDataset(valid_df, image_dir, tokenizer, image_mapping)
    test_dataset = HarmfulContentDataset(test_df, image_dir, tokenizer, image_mapping)
    
    # Create dataloaders
    batch_size = 16  # DenseNet121 might allow for similar batch sizes as ResNet50
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2)
    
    # Initialize model with DenseNet121
    model = DenseNet121BertClassifier(num_classes=2).to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-5)
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    
    # Train model
    print("Starting training...")
    train_losses, valid_losses, train_accuracies, valid_accuracies = train_model(
        model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs=10
    )
    
    # Plot training curves
    plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies)
    
    # Load best model for evaluation
    model.load_state_dict(torch.load('best_densenet_bert_model.pth'))
    
    # Evaluate model
    print("\nEvaluating model on test set...")
    accuracy, conf_matrix, class_report = evaluate_model(model, test_loader)
    
    # Save final model with metadata
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'accuracy': accuracy,
        'conf_matrix': conf_matrix,
        'class_report': class_report,
    }, 'densenet_harmful_content_classifier.pth')
    
    print("DenseNet121 model training and evaluation complete!")

if __name__ == "__main__":
    main()
# Out:
# Using device: cuda:0
# Dataset loaded with shape: (25600, 11)
#
# === Dataset Inspection ===
# Dataset columns: ['ids', 'name', 'text', 'label', 'id', 'gender', 'age', 'age_bucket', 'dominant_emotion', 'dominant_race', 'translated_text']
# Number of rows: 25600
# Label distribution: {1: 17388, 0: 8212}
# Number of image files in directory: 25716
# Sample image filenames: ['eng476.png', 'meme_184.png', 'tangaila (166).jpg', 'Image- (178).jpg', 'Image- (2026).jpg']
#
# Sample names from dataset:
# ['tangaila (1).jpg', 'tangaila (2).jpg', 'tangaila (3).jpg', 'tangaila (4).jpg', 'tangaila (5).jpg']
# Number of exact matches between 'name' column and image filenames: 18670
#
# Sample values from 'ids' column:
# [1, 2, 3, 4, 5]
# Found matches for ID 1: ['meme_184.png', 'tangaila (166).jpg']
# Found matches for ID 2: ['Image- (2026).jpg', 'image_ (2682).jpg']
# Found matches for ID 3: ['Bangla Thug Life (374).jpg', '37825.png']
# Found matches for ID 4: ['eng476.png', 'meme_184.png']
# Found matches for ID 5: ['52691.png', '37825.png']
# Found 25716 images in directory
# Sample image filenames: ['79605.png', '81064.png', '93071.png', 'Image- (4512).jpg', '86354.png']
# Sample names from dataset: ['tangaila (1).jpg', 'tangaila (2).jpg', 'tangaila (3).jpg', 'tangaila (4).jpg', 'tangaila (5).jpg']
# Successfully mapped 25432 out of 25432 unique names
# Train set: 17920, Validation set: 3840, Test set: 3840
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Starting training...
# Epoch 1, Batch 10/1120, Loss: 0.6739
# Epoch 1, Batch 20/1120, Loss: 0.6676
# Epoch 1, Batch 30/1120, Loss: 0.7318
# Epoch 1, Batch 40/1120, Loss: 0.6371
# Epoch 1, Batch 50/1120, Loss: 0.4627
# Epoch 1, Batch 60/1120, Loss: 0.7656
# Epoch 1, Batch 70/1120, Loss: 0.4765
# Epoch 1, Batch 80/1120, Loss: 0.5085
# Epoch 1, Batch 90/1120, Loss: 0.5868
# Epoch 1, Batch 100/1120, Loss: 0.5546
# Epoch 1, Batch 110/1120, Loss: 0.4938
# Epoch 1, Batch 120/1120, Loss: 0.4006
# Epoch 1, Batch 130/1120, Loss: 0.4682
# Epoch 1, Batch 140/1120, Loss: 0.6584
# Epoch 1, Batch 150/1120, Loss: 0.5215
# Epoch 1, Batch 160/1120, Loss: 0.4720
# Epoch 1, Batch 170/1120, Loss: 0.4048
# Epoch 1, Batch 180/1120, Loss: 0.5227
# Epoch 1, Batch 190/1120, Loss: 0.4811
# Epoch 1, Batch 200/1120, Loss: 0.6557
# Epoch 1, Batch 210/1120, Loss: 0.3158
# Epoch 1, Batch 220/1120, Loss: 0.6359
# Epoch 1, Batch 230/1120, Loss: 0.5098
# Epoch 1, Batch 240/1120, Loss: 0.4960
# Epoch 1, Batch 250/1120, Loss: 0.6914
# Epoch 1, Batch 260/1120, Loss: 0.4508
# Epoch 1, Batch 270/1120, Loss: 0.6613
# Epoch 1, Batch 280/1120, Loss: 0.5513
# Epoch 1, Batch 290/1120, Loss: 0.3991
# Epoch 1, Batch 300/1120, Loss: 0.6291
# Epoch 1, Batch 310/1120, Loss: 0.5485
# Epoch 1, Batch 320/1120, Loss: 0.5024
# Epoch 1, Batch 330/1120, Loss: 0.7955
# Epoch 1, Batch 340/1120, Loss: 0.3077
# Epoch 1, Batch 350/1120, Loss: 0.4439
# Epoch 1, Batch 360/1120, Loss: 0.4336
# Epoch 1, Batch 370/1120, Loss: 0.3609
# Epoch 1, Batch 380/1120, Loss: 0.5002
# Epoch 1, Batch 390/1120, Loss: 0.4247
# Epoch 1, Batch 400/1120, Loss: 0.2720
# Epoch 1, Batch 410/1120, Loss: 0.4747
# Epoch 2, Batch 950/1120, Loss: 0.3941
# Epoch 2, Batch 960/1120, Loss: 0.2992
# Epoch 2, Batch 970/1120, Loss: 0.4597
# Epoch 2, Batch 980/1120, Loss: 0.3992
# Epoch 2, Batch 990/1120, Loss: 0.3105
# Epoch 2, Batch 1000/1120, Loss: 0.2664
# Epoch 2, Batch 1010/1120, Loss: 0.2982
# Epoch 2, Batch 1020/1120, Loss: 0.2515
# Epoch 2, Batch 1030/1120, Loss: 0.3240
# Epoch 2, Batch 1040/1120, Loss: 0.3124
# Epoch 2, Batch 1050/1120, Loss: 0.7073
# Epoch 2, Batch 1060/1120, Loss: 0.4651
# Epoch 2, Batch 1070/1120, Loss: 0.2627
# Epoch 2, Batch 1080/1120, Loss: 0.3903
# Epoch 2, Batch 1090/1120, Loss: 0.4706
# Epoch 2, Batch 1100/1120, Loss: 0.6766
# Epoch 2, Batch 1110/1120, Loss: 0.3300
# Epoch 2, Batch 1120/1120, Loss: 0.5432
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 2/10, Train Loss: 0.4083, Train Acc: 0.7972, Valid Loss: 0.4121, Valid Acc: 0.7948
# Saved model with validation loss: 0.4121
# Epoch 3, Batch 10/1120, Loss: 0.3597
# Epoch 3, Batch 20/1120, Loss: 0.2024
# Epoch 3, Batch 30/1120, Loss: 0.6788
# Epoch 3, Batch 40/1120, Loss: 0.3942
# Epoch 3, Batch 50/1120, Loss: 0.3656
# Epoch 3, Batch 60/1120, Loss: 0.5870
# Epoch 3, Batch 70/1120, Loss: 0.4345
# Epoch 3, Batch 80/1120, Loss: 0.5274
# Epoch 3, Batch 90/1120, Loss: 0.2277
# Epoch 3, Batch 100/1120, Loss: 0.2306
# Epoch 3, Batch 110/1120, Loss: 0.5543
# Epoch 3, Batch 120/1120, Loss: 0.4677
# Epoch 3, Batch 130/1120, Loss: 0.5277
# Epoch 3, Batch 140/1120, Loss: 0.4433
# Epoch 3, Batch 150/1120, Loss: 0.4069
# Epoch 3, Batch 160/1120, Loss: 0.2066
# Epoch 3, Batch 170/1120, Loss: 0.2071
# Epoch 3, Batch 180/1120, Loss: 0.4698
# Epoch 3, Batch 190/1120, Loss: 0.3915
# Epoch 3, Batch 200/1120, Loss: 0.4621
# Epoch 3, Batch 210/1120, Loss: 0.2533
# Epoch 3, Batch 220/1120, Loss: 0.3263
# Epoch 3, Batch 230/1120, Loss: 0.3810
# Epoch 3, Batch 240/1120, Loss: 0.2417
# Epoch 3, Batch 250/1120, Loss: 0.3688
# Epoch 3, Batch 260/1120, Loss: 0.3305
# Epoch 3, Batch 270/1120, Loss: 0.4642
# Epoch 3, Batch 280/1120, Loss: 0.3116
# Epoch 3, Batch 290/1120, Loss: 0.7166
# Epoch 3, Batch 300/1120, Loss: 0.4617
# Epoch 3, Batch 310/1120, Loss: 0.4623
# Epoch 3, Batch 320/1120, Loss: 0.3359
# Epoch 3, Batch 330/1120, Loss: 0.3305
# Epoch 3, Batch 340/1120, Loss: 0.2882
# Epoch 3, Batch 350/1120, Loss: 0.2718
# Epoch 3, Batch 360/1120, Loss: 0.2604
# Epoch 3, Batch 370/1120, Loss: 0.2155
# Epoch 3, Batch 380/1120, Loss: 0.5208
# Epoch 3, Batch 390/1120, Loss: 0.3560
# Epoch 3, Batch 400/1120, Loss: 0.1875
# Epoch 3, Batch 410/1120, Loss: 0.4836
# Epoch 3, Batch 420/1120, Loss: 0.3082
# Epoch 3, Batch 430/1120, Loss: 0.4038
# Epoch 3, Batch 440/1120, Loss: 0.2913
# Epoch 3, Batch 450/1120, Loss: 0.2580
# Epoch 3, Batch 460/1120, Loss: 0.3054
# Epoch 3, Batch 470/1120, Loss: 0.2441
# Epoch 3, Batch 480/1120, Loss: 0.5203
# Epoch 3, Batch 490/1120, Loss: 0.2558
# Epoch 3, Batch 500/1120, Loss: 0.4048
# Epoch 3, Batch 510/1120, Loss: 0.4474
# Epoch 3, Batch 520/1120, Loss: 0.5203
# Epoch 3, Batch 530/1120, Loss: 0.1637
# Epoch 3, Batch 540/1120, Loss: 0.2940
# Epoch 3, Batch 550/1120, Loss: 0.3167
# Epoch 3, Batch 560/1120, Loss: 0.4321
# Epoch 3, Batch 570/1120, Loss: 0.3608
# Epoch 3, Batch 580/1120, Loss: 0.2416
# Epoch 3, Batch 590/1120, Loss: 0.3108
# Epoch 3, Batch 600/1120, Loss: 0.2159
# Epoch 3, Batch 610/1120, Loss: 0.5323
# Epoch 3, Batch 620/1120, Loss: 0.4462
# Epoch 3, Batch 630/1120, Loss: 0.1554
# Epoch 3, Batch 640/1120, Loss: 0.2709
# Epoch 3, Batch 650/1120, Loss: 0.3868
# Epoch 3, Batch 660/1120, Loss: 0.4810
# Epoch 3, Batch 670/1120, Loss: 0.3885
# Epoch 3, Batch 680/1120, Loss: 0.4450
# Epoch 3, Batch 690/1120, Loss: 0.2330
# Epoch 3, Batch 700/1120, Loss: 0.3474
# Epoch 3, Batch 710/1120, Loss: 0.4395
# Epoch 3, Batch 720/1120, Loss: 0.3362
# Epoch 3, Batch 730/1120, Loss: 0.4252
# Epoch 3, Batch 740/1120, Loss: 0.3304
# Epoch 3, Batch 750/1120, Loss: 0.1756
# Epoch 3, Batch 760/1120, Loss: 0.5709
# Epoch 3, Batch 770/1120, Loss: 0.3247
# Epoch 3, Batch 780/1120, Loss: 0.3009
# Epoch 3, Batch 790/1120, Loss: 0.3626
# Epoch 3, Batch 800/1120, Loss: 0.4945
# Epoch 3, Batch 810/1120, Loss: 0.3225
# Epoch 3, Batch 820/1120, Loss: 0.5939
# Epoch 3, Batch 830/1120, Loss: 0.5294
# Epoch 3, Batch 840/1120, Loss: 0.3070
# Epoch 3, Batch 850/1120, Loss: 0.4038
# Epoch 3, Batch 860/1120, Loss: 0.6085
# Epoch 3, Batch 870/1120, Loss: 0.3288
# Epoch 3, Batch 880/1120, Loss: 0.4365
# Epoch 3, Batch 890/1120, Loss: 0.4646
# Epoch 3, Batch 900/1120, Loss: 0.5951
# Epoch 3, Batch 910/1120, Loss: 0.8032
# Epoch 5, Batch 870/1120, Loss: 0.1061
# Epoch 5, Batch 880/1120, Loss: 0.2851
# Epoch 5, Batch 890/1120, Loss: 0.3375
# Epoch 5, Batch 900/1120, Loss: 0.2996
# Epoch 5, Batch 910/1120, Loss: 0.2953
# Epoch 5, Batch 920/1120, Loss: 0.1905
# Epoch 5, Batch 930/1120, Loss: 0.2971
# Epoch 5, Batch 940/1120, Loss: 0.2987
# Epoch 5, Batch 950/1120, Loss: 0.5417
# Epoch 5, Batch 960/1120, Loss: 0.1972
# Epoch 5, Batch 970/1120, Loss: 0.1830
# Epoch 5, Batch 980/1120, Loss: 0.2944
# Epoch 5, Batch 990/1120, Loss: 0.5576
# Epoch 5, Batch 1000/1120, Loss: 0.3055
# Epoch 5, Batch 1010/1120, Loss: 0.2434
# Epoch 5, Batch 1020/1120, Loss: 0.1449
# Epoch 5, Batch 1030/1120, Loss: 0.1631
# Epoch 5, Batch 1040/1120, Loss: 0.1514
# Epoch 5, Batch 1050/1120, Loss: 0.3745
# Epoch 5, Batch 1060/1120, Loss: 0.3435
# Epoch 5, Batch 1070/1120, Loss: 0.1892
# Epoch 5, Batch 1080/1120, Loss: 0.2588
# Epoch 5, Batch 1090/1120, Loss: 0.1102
# Epoch 5, Batch 1100/1120, Loss: 0.2696
# Epoch 5, Batch 1110/1120, Loss: 0.1158
# Epoch 5, Batch 1120/1120, Loss: 0.2275
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 5/10, Train Loss: 0.2680, Train Acc: 0.8837, Valid Loss: 0.4832, Valid Acc: 0.7930
# Epoch 6, Batch 10/1120, Loss: 0.1202
# Epoch 6, Batch 20/1120, Loss: 0.1461
# Epoch 6, Batch 30/1120, Loss: 0.1640
# Epoch 6, Batch 40/1120, Loss: 0.1611
# Epoch 6, Batch 50/1120, Loss: 0.2413
# Epoch 6, Batch 60/1120, Loss: 0.1585
# Epoch 6, Batch 70/1120, Loss: 0.2121
# Epoch 6, Batch 80/1120, Loss: 0.0778
# Epoch 6, Batch 90/1120, Loss: 0.0997
# Epoch 6, Batch 100/1120, Loss: 0.2428
# Epoch 6, Batch 110/1120, Loss: 0.1128
# Epoch 6, Batch 120/1120, Loss: 0.0956
# Epoch 6, Batch 130/1120, Loss: 0.1042
# Epoch 6, Batch 140/1120, Loss: 0.2323
# Epoch 6, Batch 150/1120, Loss: 0.1647
# Epoch 6, Batch 160/1120, Loss: 0.1896
# Epoch 6, Batch 170/1120, Loss: 0.2543
# Epoch 6, Batch 180/1120, Loss: 0.2892
# Epoch 6, Batch 190/1120, Loss: 0.1547
# Epoch 6, Batch 200/1120, Loss: 0.3140
# Epoch 6, Batch 210/1120, Loss: 0.1952
# Epoch 6, Batch 220/1120, Loss: 0.4480
# Epoch 6, Batch 230/1120, Loss: 0.3380
# Epoch 6, Batch 240/1120, Loss: 0.2759
# Epoch 6, Batch 250/1120, Loss: 0.3095
# Epoch 6, Batch 260/1120, Loss: 0.0641
# Epoch 6, Batch 270/1120, Loss: 0.1980
# Epoch 6, Batch 280/1120, Loss: 0.1687
# Epoch 6, Batch 290/1120, Loss: 0.2140
# Epoch 6, Batch 300/1120, Loss: 0.0690
# Epoch 6, Batch 310/1120, Loss: 0.1526
# Epoch 6, Batch 320/1120, Loss: 0.1165
# Epoch 6, Batch 330/1120, Loss: 0.0768
# Epoch 6, Batch 340/1120, Loss: 0.1139
# Epoch 6, Batch 350/1120, Loss: 0.0712
# Epoch 6, Batch 360/1120, Loss: 0.3982
# Epoch 6, Batch 370/1120, Loss: 0.2617
# Epoch 6, Batch 380/1120, Loss: 0.1767
# Epoch 6, Batch 390/1120, Loss: 0.0403
# Epoch 6, Batch 400/1120, Loss: 0.1734
# Epoch 6, Batch 410/1120, Loss: 0.1728
# Epoch 6, Batch 420/1120, Loss: 0.3606
# Epoch 6, Batch 430/1120, Loss: 0.0385
# Epoch 6, Batch 440/1120, Loss: 0.0252
# Epoch 6, Batch 450/1120, Loss: 0.2223
# Epoch 6, Batch 460/1120, Loss: 0.1259
# Epoch 6, Batch 470/1120, Loss: 0.4198
# Epoch 6, Batch 480/1120, Loss: 0.4000
# Epoch 6, Batch 490/1120, Loss: 0.3008
# Epoch 6, Batch 500/1120, Loss: 0.1494
# Epoch 6, Batch 510/1120, Loss: 0.0529
# Epoch 6, Batch 520/1120, Loss: 0.1611
# Epoch 6, Batch 530/1120, Loss: 0.1587
# Epoch 6, Batch 540/1120, Loss: 0.1208
# Epoch 6, Batch 550/1120, Loss: 0.1177
# Epoch 6, Batch 560/1120, Loss: 0.2336
# Epoch 6, Batch 570/1120, Loss: 0.2106
# Epoch 6, Batch 580/1120, Loss: 0.4886
# Epoch 6, Batch 590/1120, Loss: 0.1445
# Epoch 6, Batch 600/1120, Loss: 0.2664
# Epoch 6, Batch 610/1120, Loss: 0.1234
# Epoch 6, Batch 620/1120, Loss: 0.1046
# Epoch 6, Batch 630/1120, Loss: 0.1892
# Epoch 6, Batch 640/1120, Loss: 0.0845
# Epoch 6, Batch 650/1120, Loss: 0.1149
# Epoch 6, Batch 660/1120, Loss: 0.2835
# Epoch 6, Batch 670/1120, Loss: 0.0865
# Epoch 6, Batch 680/1120, Loss: 0.2386
# Epoch 6, Batch 690/1120, Loss: 0.5266
# Epoch 6, Batch 700/1120, Loss: 0.2377
# Epoch 6, Batch 710/1120, Loss: 0.1189
# Epoch 6, Batch 720/1120, Loss: 0.1095
# Epoch 6, Batch 730/1120, Loss: 0.1313
# Epoch 6, Batch 740/1120, Loss: 0.1786
# Epoch 6, Batch 750/1120, Loss: 0.5967
# Epoch 6, Batch 760/1120, Loss: 0.1701
# Epoch 6, Batch 770/1120, Loss: 0.1316
# Epoch 6, Batch 780/1120, Loss: 0.2800
# Epoch 6, Batch 790/1120, Loss: 0.0439
# Epoch 6, Batch 800/1120, Loss: 0.2958
# Epoch 6, Batch 810/1120, Loss: 0.3287
# Epoch 6, Batch 820/1120, Loss: 0.2705
# Epoch 6, Batch 830/1120, Loss: 0.1085
# Epoch 6, Batch 840/1120, Loss: 0.2350
# Epoch 6, Batch 850/1120, Loss: 0.1016
# Epoch 6, Batch 860/1120, Loss: 0.2262
# Epoch 6, Batch 870/1120, Loss: 0.0884
# Epoch 6, Batch 880/1120, Loss: 0.1952
# Epoch 6, Batch 890/1120, Loss: 0.3237
# Epoch 6, Batch 900/1120, Loss: 0.2064
# Epoch 6, Batch 910/1120, Loss: 0.1969
# Epoch 6, Batch 920/1120, Loss: 0.4649
# Epoch 6, Batch 930/1120, Loss: 0.2126
# Epoch 6, Batch 940/1120, Loss: 0.1643
# Epoch 6, Batch 950/1120, Loss: 0.0911
# Epoch 6, Batch 960/1120, Loss: 0.1458
# Epoch 6, Batch 970/1120, Loss: 0.2685
# Epoch 6, Batch 980/1120, Loss: 0.2988
# Epoch 6, Batch 990/1120, Loss: 0.1812
# Epoch 6, Batch 1000/1120, Loss: 0.2126
# Epoch 6, Batch 1010/1120, Loss: 0.1866
# Epoch 6, Batch 1020/1120, Loss: 0.1773
# Epoch 6, Batch 1030/1120, Loss: 0.1384
# Epoch 6, Batch 1040/1120, Loss: 0.2470
# Epoch 6, Batch 1050/1120, Loss: 0.4855
# Epoch 6, Batch 1060/1120, Loss: 0.2491
# Epoch 6, Batch 1070/1120, Loss: 0.5776
# Epoch 6, Batch 1080/1120, Loss: 0.1225
# Epoch 6, Batch 1090/1120, Loss: 0.2773
# Epoch 6, Batch 1100/1120, Loss: 0.1373
# Epoch 6, Batch 1110/1120, Loss: 0.1251
# Epoch 6, Batch 1120/1120, Loss: 0.6551
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 6/10, Train Loss: 0.2122, Train Acc: 0.9112, Valid Loss: 0.5426, Valid Acc: 0.7836
# Epoch 7, Batch 10/1120, Loss: 0.1110
# Epoch 7, Batch 20/1120, Loss: 0.1019
# Epoch 7, Batch 30/1120, Loss: 0.0947
# Epoch 7, Batch 40/1120, Loss: 0.0835
# Epoch 7, Batch 50/1120, Loss: 0.1145
# Epoch 7, Batch 60/1120, Loss: 0.0769
# Epoch 7, Batch 70/1120, Loss: 0.0349
# Epoch 7, Batch 80/1120, Loss: 0.1057
# Epoch 7, Batch 90/1120, Loss: 0.0478
# Epoch 7, Batch 100/1120, Loss: 0.1329
# Epoch 7, Batch 110/1120, Loss: 0.3512
# Epoch 7, Batch 120/1120, Loss: 0.1445
# Epoch 7, Batch 130/1120, Loss: 0.2855
# Epoch 7, Batch 140/1120, Loss: 0.0705
# Epoch 7, Batch 150/1120, Loss: 0.1047
# Epoch 7, Batch 160/1120, Loss: 0.1706
# Epoch 7, Batch 170/1120, Loss: 0.3566
# Epoch 7, Batch 180/1120, Loss: 0.1885
# Epoch 7, Batch 190/1120, Loss: 0.1996
# Epoch 7, Batch 200/1120, Loss: 0.0487
# Epoch 7, Batch 210/1120, Loss: 0.1884
# Epoch 7, Batch 220/1120, Loss: 0.1194
# Epoch 7, Batch 230/1120, Loss: 0.1677
# Epoch 7, Batch 240/1120, Loss: 0.1643
# Epoch 7, Batch 250/1120, Loss: 0.1088
# Epoch 7, Batch 820/1120, Loss: 0.1683
# Epoch 7, Batch 830/1120, Loss: 0.2327
# Epoch 7, Batch 840/1120, Loss: 0.2739
# Epoch 7, Batch 850/1120, Loss: 0.0254
# Epoch 7, Batch 860/1120, Loss: 0.0704
# Epoch 7, Batch 870/1120, Loss: 0.0804
# Epoch 7, Batch 880/1120, Loss: 0.3785
# Epoch 7, Batch 890/1120, Loss: 0.0782
# Epoch 7, Batch 900/1120, Loss: 0.2757
# Epoch 7, Batch 910/1120, Loss: 0.0528
# Epoch 7, Batch 920/1120, Loss: 0.1368
# Epoch 7, Batch 930/1120, Loss: 0.0186
# Epoch 7, Batch 940/1120, Loss: 0.2197
# Epoch 7, Batch 950/1120, Loss: 0.2109
# Epoch 7, Batch 960/1120, Loss: 0.0556
# Epoch 7, Batch 970/1120, Loss: 0.0268
# Epoch 7, Batch 980/1120, Loss: 0.0503
# Epoch 7, Batch 990/1120, Loss: 0.4089
# Epoch 7, Batch 1000/1120, Loss: 0.4187
# Epoch 7, Batch 1010/1120, Loss: 0.6287
# Epoch 7, Batch 1020/1120, Loss: 0.2766
# Epoch 7, Batch 1030/1120, Loss: 0.0604
# Epoch 7, Batch 1040/1120, Loss: 0.2178
# Epoch 7, Batch 1050/1120, Loss: 0.0233
# Epoch 7, Batch 1060/1120, Loss: 0.0929
# Epoch 7, Batch 1070/1120, Loss: 0.1809
# Epoch 7, Batch 1080/1120, Loss: 0.1359
# Epoch 7, Batch 1090/1120, Loss: 0.0382
# Epoch 7, Batch 1100/1120, Loss: 0.0408
# Epoch 7, Batch 1110/1120, Loss: 0.1043
# Epoch 7, Batch 1120/1120, Loss: 0.1050
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 7/10, Train Loss: 0.1510, Train Acc: 0.9403, Valid Loss: 0.6342, Valid Acc: 0.7839
# Epoch 8, Batch 10/1120, Loss: 0.0269
# Epoch 8, Batch 20/1120, Loss: 0.1619
# Epoch 8, Batch 30/1120, Loss: 0.0990
# Epoch 8, Batch 40/1120, Loss: 0.0403
# Epoch 8, Batch 50/1120, Loss: 0.0783
# Epoch 8, Batch 60/1120, Loss: 0.0393
# Epoch 8, Batch 70/1120, Loss: 0.0244
# Epoch 8, Batch 80/1120, Loss: 0.0659
# Epoch 8, Batch 90/1120, Loss: 0.0243
# Epoch 8, Batch 100/1120, Loss: 0.0601
# Epoch 8, Batch 110/1120, Loss: 0.0980
# Epoch 8, Batch 120/1120, Loss: 0.0772
# Epoch 8, Batch 130/1120, Loss: 0.0271
# Epoch 8, Batch 140/1120, Loss: 0.0455
# Epoch 8, Batch 150/1120, Loss: 0.1020
# Epoch 8, Batch 160/1120, Loss: 0.1979
# Epoch 8, Batch 170/1120, Loss: 0.0917
# Epoch 8, Batch 180/1120, Loss: 0.0142
# Epoch 8, Batch 190/1120, Loss: 0.0808
# Epoch 8, Batch 200/1120, Loss: 0.2438
# Epoch 8, Batch 210/1120, Loss: 0.2795
# Epoch 8, Batch 220/1120, Loss: 0.5865
# Epoch 8, Batch 230/1120, Loss: 0.0389
# Epoch 9, Batch 780/1120, Loss: 0.1802
# Epoch 9, Batch 790/1120, Loss: 0.1464
# Epoch 9, Batch 800/1120, Loss: 0.1543
# Epoch 9, Batch 810/1120, Loss: 0.2194
# Epoch 9, Batch 820/1120, Loss: 0.2735
# Epoch 9, Batch 830/1120, Loss: 0.0217
# Epoch 9, Batch 840/1120, Loss: 0.0852
# Epoch 9, Batch 850/1120, Loss: 0.0265
# Epoch 9, Batch 860/1120, Loss: 0.0353
# Epoch 9, Batch 870/1120, Loss: 0.0562
# Epoch 9, Batch 880/1120, Loss: 0.0417
# Epoch 9, Batch 890/1120, Loss: 0.2840
# Epoch 9, Batch 900/1120, Loss: 0.0418
# Epoch 9, Batch 910/1120, Loss: 0.0954
# Epoch 9, Batch 920/1120, Loss: 0.0347
# Epoch 9, Batch 930/1120, Loss: 0.1154
# Epoch 9, Batch 940/1120, Loss: 0.0318
# Epoch 9, Batch 950/1120, Loss: 0.5193
# Epoch 9, Batch 960/1120, Loss: 0.0130
# Epoch 9, Batch 970/1120, Loss: 0.0685
# Epoch 9, Batch 980/1120, Loss: 0.2344
# Epoch 9, Batch 990/1120, Loss: 0.2336
# Epoch 9, Batch 1000/1120, Loss: 0.6388
# Epoch 9, Batch 1010/1120, Loss: 0.0073
# Epoch 9, Batch 1020/1120, Loss: 0.3081
# Epoch 9, Batch 1030/1120, Loss: 0.1428
# Epoch 9, Batch 1040/1120, Loss: 0.1200
# Epoch 9, Batch 1050/1120, Loss: 0.1073
# Epoch 9, Batch 1060/1120, Loss: 0.0322
# Epoch 9, Batch 1070/1120, Loss: 0.2250
# Epoch 9, Batch 1080/1120, Loss: 0.0927
# Epoch 9, Batch 1090/1120, Loss: 0.0409
# Epoch 9, Batch 1100/1120, Loss: 0.1575
# Epoch 9, Batch 1110/1120, Loss: 0.2121
# Epoch 9, Batch 1120/1120, Loss: 0.0783
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 9/10, Train Loss: 0.1092, Train Acc: 0.9579, Valid Loss: 0.7163, Valid Acc: 0.7810
# Epoch 10, Batch 10/1120, Loss: 0.1872
# Epoch 10, Batch 20/1120, Loss: 0.0243
# Epoch 10, Batch 30/1120, Loss: 0.0436
# Epoch 10, Batch 40/1120, Loss: 0.0323
# Epoch 10, Batch 50/1120, Loss: 0.3408
# Epoch 10, Batch 60/1120, Loss: 0.0986
# Epoch 10, Batch 70/1120, Loss: 0.0193
# Epoch 10, Batch 80/1120, Loss: 0.1222
# Epoch 10, Batch 90/1120, Loss: 0.0408
# Epoch 10, Batch 100/1120, Loss: 0.2183
# Epoch 10, Batch 110/1120, Loss: 0.0285
# Epoch 10, Batch 120/1120, Loss: 0.0168
# Epoch 10, Batch 130/1120, Loss: 0.1014
# Epoch 10, Batch 140/1120, Loss: 0.1150
# Epoch 10, Batch 150/1120, Loss: 0.0335
# Epoch 10, Batch 160/1120, Loss: 0.0573
# Epoch 10, Batch 170/1120, Loss: 0.0209
# Epoch 10, Batch 180/1120, Loss: 0.0348
# Epoch 10, Batch 190/1120, Loss: 0.1110
# Epoch 10, Batch 200/1120, Loss: 0.0411
# Epoch 10, Batch 210/1120, Loss: 0.0638
# Epoch 10, Batch 220/1120, Loss: 0.1171
# Epoch 10, Batch 230/1120, Loss: 0.0776
# Epoch 10, Batch 240/1120, Loss: 0.0536
# Epoch 10, Batch 250/1120, Loss: 0.2753
# Epoch 10, Batch 260/1120, Loss: 0.3020
# Epoch 10, Batch 270/1120, Loss: 0.2696
# Epoch 10, Batch 280/1120, Loss: 0.1374
# Epoch 10, Batch 290/1120, Loss: 0.1522
# Epoch 10, Batch 300/1120, Loss: 0.4408
# Epoch 10, Batch 310/1120, Loss: 0.0344
# Epoch 10, Batch 320/1120, Loss: 0.0339
# Epoch 10, Batch 330/1120, Loss: 0.1511
# Epoch 10, Batch 340/1120, Loss: 0.2250
# Epoch 10, Batch 350/1120, Loss: 0.2205
# Epoch 10, Batch 360/1120, Loss: 0.0876
# Epoch 10, Batch 370/1120, Loss: 0.0094
# Epoch 10, Batch 380/1120, Loss: 0.0172
# Epoch 10, Batch 390/1120, Loss: 0.0965
# Epoch 10, Batch 400/1120, Loss: 0.1109
# Epoch 10, Batch 410/1120, Loss: 0.0403
# Epoch 10, Batch 420/1120, Loss: 0.0529
# Epoch 10, Batch 430/1120, Loss: 0.0878
# Epoch 10, Batch 440/1120, Loss: 0.0809
# Epoch 10, Batch 450/1120, Loss: 0.1175
# Epoch 10, Batch 460/1120, Loss: 0.0153
# Epoch 10, Batch 470/1120, Loss: 0.0517
# Epoch 10, Batch 480/1120, Loss: 0.0560
# Epoch 10, Batch 490/1120, Loss: 0.0470
# Epoch 10, Batch 500/1120, Loss: 0.1220
# Epoch 10, Batch 510/1120, Loss: 0.0225
# Epoch 10, Batch 520/1120, Loss: 0.0268
# Epoch 10, Batch 530/1120, Loss: 0.0517
# Epoch 10, Batch 540/1120, Loss: 0.2459
# Epoch 10, Batch 550/1120, Loss: 0.3193
# Epoch 10, Batch 560/1120, Loss: 0.0131
# Epoch 10, Batch 570/1120, Loss: 0.0154
# Epoch 10, Batch 580/1120, Loss: 0.1254
# Epoch 10, Batch 590/1120, Loss: 0.0168
# Epoch 10, Batch 600/1120, Loss: 0.0130
# Epoch 10, Batch 610/1120, Loss: 0.0180
# Epoch 10, Batch 620/1120, Loss: 0.2612
# Epoch 10, Batch 630/1120, Loss: 0.1219
# Epoch 10, Batch 640/1120, Loss: 0.0078
# Epoch 10, Batch 650/1120, Loss: 0.0835
# Epoch 10, Batch 660/1120, Loss: 0.0109
# Epoch 10, Batch 670/1120, Loss: 0.0300
# Epoch 10, Batch 680/1120, Loss: 0.0356
# Epoch 10, Batch 690/1120, Loss: 0.0369
# Epoch 10, Batch 700/1120, Loss: 0.1933
# Epoch 10, Batch 710/1120, Loss: 0.0789
# Epoch 10, Batch 720/1120, Loss: 0.0050
# Epoch 10, Batch 730/1120, Loss: 0.1960
# Epoch 10, Batch 740/1120, Loss: 0.0035
# Epoch 10, Batch 750/1120, Loss: 0.0988
# Epoch 10, Batch 760/1120, Loss: 0.0529
# Epoch 10, Batch 770/1120, Loss: 0.0220
# Epoch 10, Batch 780/1120, Loss: 0.0317
# Epoch 10, Batch 790/1120, Loss: 0.0335
# Epoch 10, Batch 800/1120, Loss: 0.1929
# Epoch 10, Batch 810/1120, Loss: 0.0089
# Epoch 10, Batch 820/1120, Loss: 0.1379
# Epoch 10, Batch 830/1120, Loss: 0.0727
# Epoch 10, Batch 840/1120, Loss: 0.0600
# Epoch 10, Batch 850/1120, Loss: 0.1559
# Epoch 10, Batch 860/1120, Loss: 0.1094
# Epoch 10, Batch 870/1120, Loss: 0.0673
# Epoch 10, Batch 880/1120, Loss: 0.0752
# Epoch 10, Batch 890/1120, Loss: 0.1178
# Epoch 10, Batch 900/1120, Loss: 0.0163
# Epoch 10, Batch 910/1120, Loss: 0.0444
# Epoch 10, Batch 920/1120, Loss: 0.0606
# Epoch 10, Batch 930/1120, Loss: 0.0388
# Epoch 10, Batch 940/1120, Loss: 0.0280
# Epoch 10, Batch 950/1120, Loss: 0.0100
# Epoch 10, Batch 960/1120, Loss: 0.0118
# Epoch 10, Batch 970/1120, Loss: 0.2225
# Epoch 10, Batch 980/1120, Loss: 0.1479
# Epoch 10, Batch 990/1120, Loss: 0.0466
# Epoch 10, Batch 1000/1120, Loss: 0.0086
# Epoch 10, Batch 1010/1120, Loss: 0.1931
# Epoch 10, Batch 1020/1120, Loss: 0.0121
# Epoch 10, Batch 1030/1120, Loss: 0.1205
# Epoch 10, Batch 1040/1120, Loss: 0.0552
# Epoch 10, Batch 1050/1120, Loss: 0.0381
# Epoch 10, Batch 1060/1120, Loss: 0.1266
# Epoch 10, Batch 1070/1120, Loss: 0.0217
# Epoch 10, Batch 1080/1120, Loss: 0.1039
# Epoch 10, Batch 1090/1120, Loss: 0.2246
# Epoch 10, Batch 1100/1120, Loss: 0.2670
# Epoch 10, Batch 1110/1120, Loss: 0.0514
# Epoch 10, Batch 1120/1120, Loss: 0.0794
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 10/10, Train Loss: 0.0857, Train Acc: 0.9685, Valid Loss: 0.7908, Valid Acc: 0.7841
# /tmp/ipykernel_31/1525849083.py:475: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_densenet_bert_model.pth'))
# Evaluating model on test set...
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Test Accuracy: 0.8086
#
# Confusion Matrix:
# [[ 874  358]
#  [ 377 2231]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Harmful       0.70      0.71      0.70      1232
#      Harmful       0.86      0.86      0.86      2608
#
#     accuracy                           0.81      3840
#    macro avg       0.78      0.78      0.78      3840
# weighted avg       0.81      0.81      0.81      3840
# DenseNet121 model training and evaluation complete!

# %% [markdown]
# # Load and use DenseNet121

# %%
import torch
from transformers import BertTokenizer
from torchvision import models, transforms
from PIL import Image
import requests
from io import BytesIO
import torch.nn as nn
from transformers import BertModel

# 1. Define the model architecture again (same as the one used during training)
class DenseNet121BertClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(DenseNet121BertClassifier, self).__init__()
        
        # Load pretrained DenseNet121
        self.densenet = models.densenet121(pretrained=True)
        
        # Remove the classification layer
        self.densenet.classifier = nn.Identity()
        
        # Load pre-trained BERT
        self.bert = BertModel.from_pretrained("bert-base-multilingual-cased")
        
        # Freeze DenseNet weights
        for param in self.densenet.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of DenseNet
        for param in self.densenet.features.denseblock4.parameters():
            param.requires_grad = True
        for param in self.densenet.features.transition3.parameters():
            param.requires_grad = True
        
        # Freeze BERT weights
        for param in self.bert.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of BERT
        for param in self.bert.encoder.layer[-2:].parameters():
            param.requires_grad = True
        
        # Dimensionality of DenseNet and BERT embeddings
        densenet_hidden_size = 1024  # DenseNet121 output feature size
        bert_hidden_size = self.bert.config.hidden_size  # 768 for BERT base
        
        # Enhanced classification head
        self.classifier = nn.Sequential(
            nn.Linear(densenet_hidden_size + bert_hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
        
    def forward(self, input_ids, attention_mask, image):
        # Process image with DenseNet121
        image_features = self.densenet.features(image)
        image_features = nn.functional.adaptive_avg_pool2d(image_features, (1, 1))
        image_features = image_features.view(image_features.size(0), -1)  # Flatten the features
        
        # Process text with BERT
        bert_outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        bert_embeddings = bert_outputs.last_hidden_state[:, 0, :]  # CLS token
        
        # Concatenate image and text features
        combined_embeddings = torch.cat((image_features, bert_embeddings), dim=1)
        
        # Classification
        logits = self.classifier(combined_embeddings)
        
        return logits

# 2. Load the saved model weights
def load_model(model, model_path):
    model.load_state_dict(torch.load(model_path))
    model.eval()  # Set the model to evaluation mode
    return model

# 3. Set device and load the model
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Initialize the model
model = DenseNet121BertClassifier(num_classes=2).to(device)

# Load the saved model
model_path = '/kaggle/working/best_densenet_bert_model.pth'  # Path to the saved model
model = load_model(model, model_path)

# 4. Prepare the preprocessing functions for text and image

def preprocess_text(text, tokenizer, max_length=512):
    """Preprocesses the text input for BERT model"""
    inputs = tokenizer(text, return_tensors='pt', truncation=True, padding=True, max_length=max_length)
    return inputs['input_ids'].squeeze(0), inputs['attention_mask'].squeeze(0)

def preprocess_image(image_path, transform):
    """Preprocesses the image input for DenseNet121"""
    # Open image
    if image_path.startswith('http') or image_path.startswith('https'):
        response = requests.get(image_path)
        img = Image.open(BytesIO(response.content))
    else:
        img = Image.open(image_path)
    
    # Apply necessary transformations
    img = transform(img).unsqueeze(0)  # Add batch dimension
    return img

# 5. Perform inference on a single text and image
def predict(model, text, image_path, tokenizer, transform, device):
    # Tokenize the text and ensure it returns the correct format
    encoding = tokenizer(text, padding=True, truncation=True, return_tensors="pt", max_length=512)
    
    # Get the input_ids and attention_mask
    input_ids = encoding['input_ids'].to(device)
    attention_mask = encoding['attention_mask'].to(device)
    
    # Load and preprocess the image
    image = Image.open(image_path).convert("RGB")
    image = transform(image).unsqueeze(0).to(device)  # Add batch dimension
    
    # Run the model
    with torch.no_grad():
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=image)
    
    # Get the predicted label
    _, predicted_label = torch.max(outputs, dim=1)
    
    return predicted_label.item()

# Initialize the tokenizer and transform for the image
tokenizer = BertTokenizer.from_pretrained('bert-base-multilingual-cased')

# Transform for the image (DenseNet121 expects normalized input)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
# Out:
# Using device: cuda:0
# /tmp/ipykernel_31/3969772450.py:77: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(model_path))
# Predicted label: 0

# %%
# Example inputs
text = "when you're feeling horny asf but your habibi is on periods let's try a goat. [Label: 1 | ID: 1235 | Gender: man | Age: 43 | Age Bucket: 40-50 | Dominant Emotion: happy | Dominant Race: middle eastern]"
image_path = "/kaggle/input/multilingual-meme-datasets/datasets/datasets/38105.png"

# Make the prediction
prediction = predict(model, text, image_path, tokenizer, transform, device)

# Output the prediction (e.g., print the label)
print(f"Predicted label: {prediction}")
# Out:
# Predicted label: 0
