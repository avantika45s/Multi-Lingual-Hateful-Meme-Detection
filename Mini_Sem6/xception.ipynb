# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer, BertModel
import re
import glob
# Out:
# 2025-04-17 17:10:57.586590: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744909857.608811     129 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744909857.615645     129 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load dataset
df = pd.read_csv('/kaggle/input/multilingual-datasets/final_datasets.csv')
print(f"Dataset loaded with shape: {df.shape}")

# Image directory
image_dir = "/kaggle/input/multilingual-meme-datasets/datasets/datasets"
# Out:
# Using device: cuda:0
# Dataset loaded with shape: (25600, 11)

# %%
def create_image_mapping(dataframe, image_directory):
    """
    Create a mapping between dataset 'name' column and actual image filenames in the directory.
    This handles the case where image filenames might have different formats.
    """
    # Get all image files in the directory
    image_files = glob.glob(os.path.join(image_directory, '*'))
    image_mapping = {}
    
    # Create a set of all available image filenames (without path)
    available_images = {os.path.basename(f) for f in image_files}
    print(f"Found {len(available_images)} images in directory")
    
    # Print some sample images to understand the naming pattern
    print("Sample image filenames:", list(available_images)[:5])
    
    # Print some sample names from the dataset
    print("Sample names from dataset:", dataframe['name'].iloc[:5].tolist())
    
    # Method 1: Exact match
    for name in dataframe['name'].unique():
        if name in available_images:
            image_mapping[name] = name
    
    # Method 2: Check if the id is part of the filename
    unmapped_names = set(dataframe['name']) - set(image_mapping.keys())
    for name in unmapped_names:
        # Extract ID from name (assuming name has some ID pattern)
        id_match = re.search(r'\d+', name)
        if id_match:
            id_value = id_match.group()
            # Look for files containing this ID
            matching_files = [f for f in available_images if id_value in f]
            if matching_files:
                image_mapping[name] = matching_files[0]
    
    # Method 3: Try matching using 'ids' or 'id' column if available
    if 'ids' in dataframe.columns or 'id' in dataframe.columns:
        id_col = 'ids' if 'ids' in dataframe.columns else 'id'
        id_to_name = dict(zip(dataframe[id_col], dataframe['name']))
        
        for id_value, name in id_to_name.items():
            if name not in image_mapping:
                # Look for files containing this ID
                matching_files = [f for f in available_images if str(id_value) in f]
                if matching_files:
                    image_mapping[name] = matching_files[0]
    
    print(f"Successfully mapped {len(image_mapping)} out of {len(dataframe['name'].unique())} unique names")
    return image_mapping

# %%
# Custom dataset class with image mapping for ResNet50
class HarmfulContentDataset(Dataset):
    def __init__(self, dataframe, image_dir, tokenizer, image_mapping=None, max_len=128):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.image_mapping = image_mapping or {}
        
        # Create a default blank image to use when an image is not found
        self.blank_image = Image.new('RGB', (224, 224), color='white')
        
        # Image transformation for ResNet50
        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Text features
        text_features = f"{row['gender']} {row['age']} {row['age_bucket']} {row['dominant_emotion']} {row['dominant_race']} {row['translated_text']}"
        
        # Tokenize text
        encoding = self.tokenizer.encode_plus(
            text_features,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        
        # Image processing
        try:
            # Get the correct image filename using the mapping
            image_filename = self.image_mapping.get(row['name'], row['name'])
            image_path = os.path.join(self.image_dir, image_filename)
            
            # Check if the file exists
            if os.path.exists(image_path):
                image = Image.open(image_path).convert('RGB')
            else:
                # Try alternate approach: check if the file exists with different extensions
                base_name = os.path.splitext(image_path)[0]
                for ext in ['.jpg', '.jpeg', '.png', '.gif']:
                    alt_path = base_name + ext
                    if os.path.exists(alt_path):
                        image = Image.open(alt_path).convert('RGB')
                        break
                else:
                    # If still not found, use blank image
                    image = self.blank_image
                    if idx % 100 == 0:  # Limit logging to avoid flooding
                        print(f"Image not found for {row['name']}, using blank image")
            
            # Apply transformations for ResNet50
            image_tensor = self.transform(image)
            
        except Exception as e:
            if idx % 100 == 0:  # Limit logging
                print(f"Error processing image for {row['name']}: {e}")
            # Create blank image features
            image_tensor = torch.zeros((3, 224, 224))
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'image': image_tensor,
            'labels': torch.tensor(row['label'], dtype=torch.long)
        }

# %%
pip install timm
# Out:
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (1.0.14)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from timm) (2.5.1+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from timm) (0.20.1+cu124)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from timm) (6.0.2)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm) (0.30.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm) (0.5.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm) (4.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->timm) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->timm) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision->timm) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->timm) (3.0.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->torchvision->timm) (2.4.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface_hub->timm) (2025.1.31)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision->timm) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->torchvision->timm) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->torchvision->timm) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->torchvision->timm) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->torchvision->timm) (2024.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
from transformers import BertModel
import timm  # Xception is available here

class XceptionBertClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(XceptionBertClassifier, self).__init__()

        # Load pretrained Xception model from timm
        self.xception = timm.create_model('xception', pretrained=True, num_classes=0)  # output is feature vector
        
        # Freeze all Xception parameters initially
        for param in self.xception.parameters():
            param.requires_grad = False
        
        # Unfreeze last few layers for fine-tuning
        for param in list(self.xception.parameters())[-40:]:
            param.requires_grad = True
        
        # Load pre-trained BERT
        self.bert = BertModel.from_pretrained("bert-base-multilingual-cased")
        
        # Freeze all BERT parameters initially
        for param in self.bert.parameters():
            param.requires_grad = False
        
        # Unfreeze last 2 encoder layers for fine-tuning
        for param in self.bert.encoder.layer[-2:].parameters():
            param.requires_grad = True

        # Get the output size of Xception
        xception_output_dim = self.xception.num_features  # typically 2048
        bert_output_dim = self.bert.config.hidden_size  # usually 768

        # Final classifier
        self.classifier = nn.Sequential(
            nn.Linear(xception_output_dim + bert_output_dim, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )

    def forward(self, input_ids, attention_mask, image):
        # Image feature extraction (Xception)
        image_features = self.xception(image)  # (B, 2048)
        
        # Text feature extraction (BERT)
        bert_outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        bert_cls_embedding = bert_outputs.last_hidden_state[:, 0, :]  # (B, 768)
        
        # Combine
        combined = torch.cat((image_features, bert_cls_embedding), dim=1)
        logits = self.classifier(combined)
        
        return logits

# %%
def train_model(model, train_loader, valid_loader, criterion, optimizer, scheduler=None, num_epochs=10):
    train_losses = []
    valid_losses = []
    train_accuracies = []
    valid_accuracies = []
    
    best_valid_loss = float('inf')
    
    for epoch in range(num_epochs):
        # Training
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for batch_idx, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            optimizer.zero_grad()
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            
            # Print batch progress
            if (batch_idx + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
        
        train_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        
        # Validation
        model.eval()
        running_valid_loss = 0.0
        correct_valid = 0
        total_valid = 0
        
        with torch.no_grad():
            for batch in valid_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                images = batch['image'].to(device)
                labels = batch['labels'].to(device)
                
                outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
                loss = criterion(outputs, labels)
                
                running_valid_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total_valid += labels.size(0)
                correct_valid += (predicted == labels).sum().item()
        
        valid_loss = running_valid_loss / len(valid_loader)
        valid_accuracy = correct_valid / total_valid
        valid_losses.append(valid_loss)
        valid_accuracies.append(valid_accuracy)
        
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, '
              f'Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_accuracy:.4f}')
        
        # Update scheduler if provided
        if scheduler is not None:
            scheduler.step(valid_loss)
        
        # Save best model
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), 'best_xception_bert_model.pth')
            print(f'Saved model with validation loss: {valid_loss:.4f}')
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# %%
def evaluate_model(model, test_loader):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            _, predicted = torch.max(outputs.data, 1)
            
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    conf_matrix = confusion_matrix(y_true, y_pred)
    class_report = classification_report(y_true, y_pred, target_names=['Non-Harmful', 'Harmful'])
    
    print(f'Test Accuracy: {accuracy:.4f}')
    print('\nConfusion Matrix:')
    print(conf_matrix)
    print('\nClassification Report:')
    print(class_report)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Harmful', 'Harmful'], 
                yticklabels=['Non-Harmful', 'Harmful'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig('xception_confusion_matrix.png')
    plt.show()
    
    return accuracy, conf_matrix, class_report

# %%
def plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies):
    # Plot loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(valid_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('xception_training_curves.png')
    plt.show()

# %%
def main():
    # Initialize tokenizer for BERT
    tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
    
    # Inspect dataset and image directory
    image_files = inspect_dataset(df, image_dir)
    
    # Create mapping between dataset names and image filenames
    image_mapping = create_image_mapping(df, image_dir)
    
    # Split dataset
    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, stratify=df['label'])
    valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['label'])
    
    print(f"Train set: {len(train_df)}, Validation set: {len(valid_df)}, Test set: {len(test_df)}")
    
    # Create datasets with image mapping
    train_dataset = HarmfulContentDataset(train_df, image_dir, tokenizer, image_mapping)
    valid_dataset = HarmfulContentDataset(valid_df, image_dir, tokenizer, image_mapping)
    test_dataset = HarmfulContentDataset(test_df, image_dir, tokenizer, image_mapping)
    
    # Create dataloaders
    batch_size = 16  
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2)
    
    # Initialize model with ResNet50
    model = XceptionBertClassifier(num_classes=2).to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-5)
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    
    # Train model
    print("Starting training...")
    train_losses, valid_losses, train_accuracies, valid_accuracies = train_model(
        model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs=10
    )
    
    # Plot training curves
    plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies)
    
    # Load best model for evaluation
    model.load_state_dict(torch.load('best_xception_bert_model.pth'))
    
    # Evaluate model
    print("\nEvaluating model on test set...")
    accuracy, conf_matrix, class_report = evaluate_model(model, test_loader)
    
    # Save final model with metadata
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'accuracy': accuracy,
        'conf_matrix': conf_matrix,
        'class_report': class_report,
    }, 'xception_harmful_content_classifier.pth')
    
    print("xception model training and evaluation complete!")

# %%
def inspect_dataset(df, image_dir):
    """
    Inspects the dataset and the image directory to understand the structure.
    """
    print("\n=== Dataset Inspection ===")
    print(f"Dataset columns: {df.columns.tolist()}")
    print(f"Number of rows: {len(df)}")
    print(f"Label distribution: {df['label'].value_counts().to_dict()}")
    
    # Check if image directory exists
    if not os.path.exists(image_dir):
        print(f"WARNING: Image directory does not exist: {image_dir}")
        return
    
    # Count image files
    image_files = [f for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f)) and 
                   f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
    
    print(f"Number of image files in directory: {len(image_files)}")
    if len(image_files) > 0:
        print(f"Sample image filenames: {image_files[:5]}")
    
    # Check name column format
    print("\nSample names from dataset:")
    print(df['name'].head(5).tolist())
    
    # Check if any dataset names exactly match image filenames
    matching_names = [name for name in df['name'].unique() if name in image_files]
    print(f"Number of exact matches between 'name' column and image filenames: {len(matching_names)}")
    
    # Check if IDs are in the name column
    if 'id' in df.columns or 'ids' in df.columns:
        id_col = 'ids' if 'ids' in df.columns else 'id'
        print(f"\nSample values from '{id_col}' column:")
        print(df[id_col].head(5).tolist())
        
        # Check if IDs are in image filenames
        sample_ids = df[id_col].astype(str).head(5).tolist()
        for id_val in sample_ids:
            matches = [f for f in image_files if id_val in f]
            if matches:
                print(f"Found matches for ID {id_val}: {matches[:2]}")
                
    return image_files

if __name__ == "__main__":
    main()
# Out:
# === Dataset Inspection ===
# Dataset columns: ['ids', 'name', 'text', 'label', 'id', 'gender', 'age', 'age_bucket', 'dominant_emotion', 'dominant_race', 'translated_text']
# Number of rows: 25600
# Label distribution: {1: 17388, 0: 8212}
# WARNING: Image directory does not exist: /kaggle/input/multilingual-meme-datasets/datasets/datasets
# Found 0 images in directory
# Sample image filenames: []
# Sample names from dataset: ['tangaila (1).jpg', 'tangaila (2).jpg', 'tangaila (3).jpg', 'tangaila (4).jpg', 'tangaila (5).jpg']
# Successfully mapped 0 out of 25432 unique names
# Train set: 17920, Validation set: 3840, Test set: 3840
# /usr/local/lib/python3.11/dist-packages/timm/models/_factory.py:126: UserWarning: Mapping deprecated model name xception to current legacy_xception.
#   model = create_fn(
# Starting training...
# Epoch 1, Batch 10/1120, Loss: 0.6987
# Image not found for 98734.png, using blank image
# Epoch 1, Batch 20/1120, Loss: 0.6126
# Image not found for 14852.png, using blank image
# Epoch 1, Batch 30/1120, Loss: 0.6823
# Image not found for KAM (393).jpg, using blank image
# Image not found for ovodro_img (717).jpg, using blank image
# Image not found for ovodro_img (237).jpg, using blank image
# Image not found for meme_559.png, using blank image
# Image not found for image_ (3451).jpg, using blank image
# Epoch 1, Batch 40/1120, Loss: 0.5722
# Image not found for 19385.png, using blank image
# Image not found for Image_(1505).jpg, using blank image
# Image not found for meme_133.png, using blank image
# Image not found for 71863.png, using blank image
# Epoch 1, Batch 50/1120, Loss: 0.5510
# Image not found for 48790.png, using blank image
# Epoch 1, Batch 60/1120, Loss: 0.6189
# Image not found for eng176.png, using blank image
# Image not found for 06458.png, using blank image
# Epoch 1, Batch 70/1120, Loss: 0.5087
# Epoch 1, Batch 80/1120, Loss: 0.6927
# Image not found for image_ (1462).jpg, using blank image
# Image not found for direct-offense (21).jpg, using blank image
# Image not found for Image_(3253).jpg, using blank image
# Image not found for meme_175.png, using blank image
# Image not found for 60741.png, using blank image
# Image not found for image_ (2257).jpg, using blank image
# Image not found for chosha (78).jpg, using blank image
# Image not found for bangla-troll (27).jpg, using blank image
# Image not found for 18497.png, using blank image
# Image not found for 62197.png, using blank image
# Image not found for eng165.png, using blank image
# Image not found for 50683.png, using blank image
# Image not found for 19567.png, using blank image
# Image not found for KAM (32).jpg, using blank image
# Image not found for 39612.png, using blank image
# Image not found for Image_(1796).jpg, using blank image
# Image not found for image_ (1177).jpg, using blank image
# Image not found for bamboo-vaiya (379).jpg, using blank image
# Image not found for Image_(3475).jpg, using blank image
# Image not found for 41087.png, using blank image
# Image not found for 62703.png, using blank image
# Image not found for Image_(189).jpg, using blank image
# Image not found for 95712.png, using blank image
# Image not found for image_ (1949).jpg, using blank image
# Image not found for Image_(497).jpg, using blank image
# Image not found for 54976.png, using blank image
# Image not found for Image_(3029).jpg, using blank image
# Image not found for ovodro_img (494).jpg, using blank image
# Image not found for image_ (3777).jpg, using blank image
# Epoch 2/10, Train Loss: 0.4471, Train Acc: 0.7720, Valid Loss: 14615.4082, Valid Acc: 0.6792
# Saved model with validation loss: 14615.4082
# Image not found for 75892.png, using blank image
# Image not found for ovodro_img (541).jpg, using blank image
# Image not found for 35869.png, using blank image
# Image not found for 17230.png, using blank image
# Epoch 3, Batch 10/1120, Loss: 0.4587
# Image not found for eng176.png, using blank image
# Image not found for image_ (331).jpg, using blank image
# Epoch 3, Batch 20/1120, Loss: 0.5428
# Image not found for 87392.png, using blank image
# Epoch 3, Batch 30/1120, Loss: 0.3180
# Image not found for 04361.png, using blank image
# Image not found for 41538.png, using blank image
# Epoch 3, Batch 40/1120, Loss: 0.3530
# Epoch 3, Batch 50/1120, Loss: 0.3167
# Image not found for Image_(5294).jpg, using blank image
# Image not found for image_ (1481).jpg, using blank image
# Image not found for image_ (1462).jpg, using blank image
# Epoch 3, Batch 60/1120, Loss: 0.4215
# Epoch 3, Batch 70/1120, Loss: 0.8663
# Image not found for image_ (3511).jpg, using blank image
# Image not found for 86914.png, using blank image
# Image not found for 06325.png, using blank image
# Epoch 3, Batch 80/1120, Loss: 0.6702
# Image not found for 29841.png, using blank image
# Image not found for Image_(1429).jpg, using blank image
# Image not found for ramdev46.png, using blank image
# Epoch 3, Batch 90/1120, Loss: 0.4996
# Image not found for Image_(2553).jpg, using blank image
# Image not found for image_ (3534).jpg, using blank image
# Image not found for ovodro_img (260).jpg, using blank image
# Image not found for Image_(1362).jpg, using blank image
# Image not found for 40592.png, using blank image
# Epoch 3, Batch 100/1120, Loss: 0.4130
# Epoch 3, Batch 110/1120, Loss: 0.3569
# Image not found for 62541.png, using blank image
# Epoch 3, Batch 120/1120, Loss: 0.3184
# Epoch 3, Batch 130/1120, Loss: 0.5773
# Image not found for rhea16.png, using blank image
# Epoch 3, Batch 140/1120, Loss: 0.3879
# Image not found for 64390.png, using blank image
# Image not found for 48790.png, using blank image
# Image not found for Halal Memes (110).jpg, using blank image
# Epoch 3, Batch 150/1120, Loss: 0.3723
# Image not found for 14852.png, using blank image
# Epoch 3, Batch 160/1120, Loss: 0.4361
# Image not found for 51367.png, using blank image
# Epoch 3, Batch 170/1120, Loss: 0.6250
# Image not found for image_ (3923).jpg, using blank image
# Image not found for meme_133.png, using blank image
# Epoch 3, Batch 180/1120, Loss: 0.3787
# Image not found for Image_(2698).jpg, using blank image
# Epoch 3, Batch 190/1120, Loss: 0.3782
# Image not found for meme_379.png, using blank image
# Epoch 3, Batch 200/1120, Loss: 0.7464
# Epoch 3, Batch 210/1120, Loss: 0.3641
# Image not found for 96420.png, using blank image
# Epoch 3, Batch 220/1120, Loss: 0.5050
# Image not found for 34862.png, using blank image
# Image not found for 34786.png, using blank image
# Image not found for ovodro_img (237).jpg, using blank image
# Image not found for image_ (2342).jpg, using blank image
# Epoch 3, Batch 230/1120, Loss: 0.5691
# Image not found for image_ (1403).jpg, using blank image
# Image not found for 27803.png, using blank image
# Image not found for Bangla Thug Life (341).jpg, using blank image
# Epoch 3, Batch 240/1120, Loss: 0.4149
# Epoch 3, Batch 250/1120, Loss: 0.5039
# Image not found for 16032.png, using blank image
# Image not found for Image_(2082).jpg, using blank image
# Image not found for image_ (1405).jpg, using blank image
# Epoch 3, Batch 260/1120, Loss: 0.2600
# Image not found for 01465.png, using blank image
# Image not found for Image_(1714).jpg, using blank image
# Image not found for image_ (619).jpg, using blank image
# Epoch 3, Batch 270/1120, Loss: 0.4803
# Epoch 3, Batch 280/1120, Loss: 0.4236
# Image not found for 35102.png, using blank image
# Epoch 3, Batch 290/1120, Loss: 0.6025
# Epoch 3, Batch 300/1120, Loss: 0.4346
# Image not found for 25768.png, using blank image
# Image not found for Halal Memes (181).jpg, using blank image
# Epoch 3, Batch 310/1120, Loss: 0.6670
# Image not found for tangaila (233).jpg, using blank image
# Image not found for 41830.png, using blank image
# Image not found for 31728.png, using blank image
# Epoch 3, Batch 320/1120, Loss: 0.5577
# Image not found for Image_(3516).jpg, using blank image
# Image not found for 76098.png, using blank image
# Epoch 3, Batch 330/1120, Loss: 0.4772
# Epoch 3, Batch 340/1120, Loss: 0.6678
# Image not found for Image_(5700).jpg, using blank image
# Epoch 3, Batch 350/1120, Loss: 0.3790
# Image not found for 28617.png, using blank image
# Epoch 3, Batch 360/1120, Loss: 0.4600
# Image not found for Image_(2688).jpg, using blank image
# Epoch 3, Batch 370/1120, Loss: 0.4217
# Image not found for 98734.png, using blank image
# Epoch 3, Batch 380/1120, Loss: 0.6903
# Epoch 3, Batch 390/1120, Loss: 0.4551
# Epoch 3, Batch 400/1120, Loss: 0.2694
# Epoch 3, Batch 410/1120, Loss: 0.5938
# Image not found for meme_577.png, using blank image
# Epoch 3, Batch 420/1120, Loss: 0.3652
# Image not found for image_ (2521).jpg, using blank image
# Epoch 3, Batch 430/1120, Loss: 0.3095
# Image not found for 63105.png, using blank image
# Epoch 3, Batch 440/1120, Loss: 0.6402
# Image not found for image_ (1486).jpg, using blank image
# Image not found for Image_(3369).jpg, using blank image
# Epoch 3, Batch 450/1120, Loss: 0.3772
# Epoch 3, Batch 460/1120, Loss: 0.3215
# Image not found for ovodro_img (717).jpg, using blank image
# Image not found for Image_(2152).jpg, using blank image
# Epoch 3, Batch 470/1120, Loss: 0.2606
# Image not found for 78459.png, using blank image
# Image not found for 59047.png, using blank image
# Image not found for 72386.png, using blank image
# Epoch 3, Batch 480/1120, Loss: 0.4662
# Image not found for 01763.png, using blank image
# Image not found for KAM (393).jpg, using blank image
# Epoch 3, Batch 490/1120, Loss: 0.5289
# Image not found for bamboo-vaiya (94).jpg, using blank image
# Image not found for KAM (193).jpg, using blank image
# Image not found for 71863.png, using blank image
# Epoch 3, Batch 500/1120, Loss: 0.3277
# Epoch 3, Batch 510/1120, Loss: 0.2279
# Image not found for Image_(2804).jpg, using blank image
# Epoch 3, Batch 520/1120, Loss: 0.6151
# Image not found for bamboo-vaiya (274).jpg, using blank image
# Image not found for 62571.png, using blank image
# Epoch 3, Batch 530/1120, Loss: 0.6812
# Image not found for Image_(2139).jpg, using blank image
# Image not found for Image_(3630).jpg, using blank image
# Epoch 3, Batch 540/1120, Loss: 0.3583
# Image not found for KAM (302).jpg, using blank image
# Image not found for 50784.png, using blank image
# Epoch 3, Batch 550/1120, Loss: 0.4510
# Image not found for Bangla Thug Life (372).jpg, using blank image
# Image not found for 34196.png, using blank image
# Image not found for image_ (3451).jpg, using blank image
# Image not found for image_ (1371).jpg, using blank image
# Epoch 3, Batch 560/1120, Loss: 0.5630
# Epoch 3, Batch 570/1120, Loss: 0.5563
# Image not found for Image_(1287).jpg, using blank image
# Image not found for 19385.png, using blank image
# Image not found for bangla-gag (144).jpg, using blank image
# Epoch 3, Batch 580/1120, Loss: 0.4368
# Image not found for Image_(4790).jpg, using blank image
# Image not found for 28397.png, using blank image
# Epoch 3, Batch 590/1120, Loss: 0.4065
# Epoch 3, Batch 600/1120, Loss: 0.6001
# Image not found for Image_(1505).jpg, using blank image
# Image not found for image_ (3989).jpg, using blank image
# Image not found for 57162.png, using blank image
# Image not found for Image_(2872).jpg, using blank image
# Epoch 3, Batch 610/1120, Loss: 0.3022
# Image not found for 81097.png, using blank image
# Epoch 3, Batch 620/1120, Loss: 0.3853
# Image not found for image_ (1401).jpg, using blank image
# Image not found for direct-offense (21).jpg, using blank image
# Image not found for 06458.png, using blank image
# Epoch 3, Batch 630/1120, Loss: 0.4533
# Epoch 3, Batch 640/1120, Loss: 0.3084
# Epoch 3, Batch 650/1120, Loss: 0.5545
# Image not found for Image_(4972).jpg, using blank image
# Image not found for image_ (3437).jpg, using blank image
# Image not found for image_ (2854).jpg, using blank image
# Image not found for Image_(5213).jpg, using blank image
# Epoch 3, Batch 660/1120, Loss: 0.5515
# Image not found for image_ (1724).jpg, using blank image
# Image not found for image_ (2343).jpg, using blank image
# Image not found for 75286.png, using blank image
# Image not found for 10673.png, using blank image
# Epoch 3, Batch 670/1120, Loss: 0.4748
# Image not found for image_ (431).jpg, using blank image
# Image not found for Image_(633).jpg, using blank image
# Epoch 3, Batch 680/1120, Loss: 0.4864
# Image not found for bamboo-vaiya (534).jpg, using blank image
# Image not found for image_ (3171).jpg, using blank image
# Epoch 3, Batch 690/1120, Loss: 0.4841
# Image not found for Image_(4798).jpg, using blank image
# Epoch 3, Batch 700/1120, Loss: 0.6103
# Epoch 3, Batch 710/1120, Loss: 0.2972
# Image not found for bangla-gag (31).jpg, using blank image
# Image not found for image_ (1138).jpg, using blank image
# Epoch 3, Batch 720/1120, Loss: 0.4991
# Image not found for Image_(3180).jpg, using blank image
# Image not found for 45037.png, using blank image
# Image not found for 40125.png, using blank image
# Image not found for meme_559.png, using blank image
# Epoch 3, Batch 730/1120, Loss: 0.2634
# Epoch 3, Batch 740/1120, Loss: 0.4381
# Image not found for 35074.png, using blank image
# Image not found for image_ (1003).jpg, using blank image
# Epoch 3, Batch 750/1120, Loss: 0.5764
# Image not found for Image_(1991).jpg, using blank image
# Image not found for gay108.png, using blank image
# Epoch 3, Batch 760/1120, Loss: 0.5351
# Epoch 3, Batch 770/1120, Loss: 0.1929
# Image not found for image_ (1134).jpg, using blank image
# Epoch 3, Batch 780/1120, Loss: 0.7003
# Image not found for chosha (59).jpg, using blank image
# Image not found for 01379.png, using blank image
# Epoch 3, Batch 790/1120, Loss: 0.5723
# Image not found for 09128.png, using blank image
# Epoch 3, Batch 800/1120, Loss: 0.2317
# Image not found for Image_(3253).jpg, using blank image
# Epoch 3, Batch 810/1120, Loss: 0.5027
# Image not found for 14092.png, using blank image
# Epoch 3, Batch 820/1120, Loss: 0.4431
# Image not found for Image_(2869).jpg, using blank image
# Image not found for eng370.png, using blank image
# Epoch 3, Batch 830/1120, Loss: 0.3413
# Image not found for 61280.png, using blank image
# Image not found for bamboo-vaiya (56).jpg, using blank image
# Image not found for 34768.png, using blank image
# Epoch 3, Batch 840/1120, Loss: 0.5354
# Image not found for Image_(2113).jpg, using blank image
# Epoch 3, Batch 850/1120, Loss: 0.5260
# Image not found for 17504.png, using blank image
# Image not found for ovodro_img (681).jpg, using blank image
# Image not found for Image_(3132).jpg, using blank image
# Epoch 3, Batch 860/1120, Loss: 0.4383
# Image not found for image_ (805).jpg, using blank image
# Epoch 3, Batch 870/1120, Loss: 0.4450
# Epoch 3, Batch 880/1120, Loss: 0.4911
# Image not found for 64705.png, using blank image
# Epoch 3, Batch 890/1120, Loss: 0.2352
# Image not found for 53692.png, using blank image
# Image not found for image_ (3672).jpg, using blank image
# Image not found for Image_(603).jpg, using blank image
# Epoch 3, Batch 900/1120, Loss: 0.5039
# Image not found for Halal Memes (211).jpg, using blank image
# Image not found for 62913.png, using blank image
# Image not found for Image_(2355).jpg, using blank image
# Image not found for 52780.png, using blank image
# Epoch 3, Batch 910/1120, Loss: 0.4722
# Image not found for bamboo-vaiya (223).jpg, using blank image
# Image not found for KAM (193).png, using blank image
# Image not found for Image_(5249).jpg, using blank image
# Epoch 3, Batch 920/1120, Loss: 0.4680
# Image not found for eng183.png, using blank image
# Image not found for Image_(3242).jpg, using blank image
# Image not found for Image_(1250).jpg, using blank image
# Image not found for 36842.png, using blank image
# Epoch 3, Batch 930/1120, Loss: 0.3038
# Image not found for bamboo-vaiya (247).jpg, using blank image
# Image not found for 40752.png, using blank image
# Image not found for 29430.png, using blank image
# Epoch 3, Batch 940/1120, Loss: 0.3371
# Epoch 3, Batch 950/1120, Loss: 0.3614
# Image not found for 13906.png, using blank image
# Image not found for 72035.png, using blank image
# Epoch 3, Batch 960/1120, Loss: 0.6371
# Image not found for Image_(2532).jpg, using blank image
# Epoch 3, Batch 970/1120, Loss: 0.4918
# Image not found for rhea33.png, using blank image
# Epoch 3, Batch 980/1120, Loss: 0.4326
# Image not found for 65273.png, using blank image
# Image not found for 28076.png, using blank image
# Image not found for Image_(3969).jpg, using blank image
# Epoch 3, Batch 990/1120, Loss: 0.6012
# Image not found for 61872.png, using blank image
# Epoch 3, Batch 1000/1120, Loss: 0.3633
# Image not found for KAM (519).jpg, using blank image
# Image not found for eng319.png, using blank image
# Epoch 3, Batch 1010/1120, Loss: 0.3664
# Image not found for Image_(1097).jpg, using blank image
# Epoch 3, Batch 1020/1120, Loss: 0.3873
# Image not found for 37615.png, using blank image
# Image not found for 67859.png, using blank image
# Epoch 3, Batch 1030/1120, Loss: 0.1635
# Image not found for ovodro_img (229).jpg, using blank image
# Image not found for Image_(5940).jpg, using blank image
# Epoch 3, Batch 1040/1120, Loss: 0.3799
# Image not found for Image_(1080).jpg, using blank image
# Epoch 3, Batch 1050/1120, Loss: 0.3035
# Image not found for Image_(2772).jpg, using blank image
# Image not found for 89152.png, using blank image
# Image not found for Image_(1138).jpg, using blank image
# Epoch 3, Batch 1060/1120, Loss: 0.3557
# Epoch 3, Batch 1070/1120, Loss: 0.3447
# Epoch 3, Batch 1080/1120, Loss: 0.4629
# Image not found for Image_(4763).jpg, using blank image
# Image not found for image_ (2748).jpg, using blank image
# Epoch 3, Batch 1090/1120, Loss: 0.2962
# Epoch 3, Batch 1100/1120, Loss: 0.4005
# Image not found for Image_(3748).jpg, using blank image
# Image not found for Image_(4916).jpg, using blank image
# Epoch 3, Batch 1110/1120, Loss: 0.5229
# Image not found for Image_(4912).jpg, using blank image
# Epoch 3, Batch 1120/1120, Loss: 0.3024
# Image not found for 21096.png, using blank image
# Image not found for Image_(622).jpg, using blank image
# Image not found for image_ (3294).jpg, using blank image
# Image not found for Image_(3591).jpg, using blank image
# Image not found for image_ (2869).jpg, using blank image
# Image not found for Image_(2315).jpg, using blank image
# Image not found for Image_(1643).jpg, using blank image
# Image not found for Image_(2963).jpg, using blank image
# Image not found for 45029.png, using blank image
# Image not found for Image_(352).jpg, using blank image
# Image not found for image_ (3799).jpg, using blank image
# Image not found for image_ (326).jpg, using blank image
# Image not found for 83960.png, using blank image
# Image not found for meme_175.png, using blank image
# Image not found for 60741.png, using blank image
# Image not found for image_ (2257).jpg, using blank image
# Image not found for chosha (78).jpg, using blank image
# ...
# Epoch 10, Batch 360/1120, Loss: 0.2156
# Epoch 10, Batch 370/1120, Loss: 0.2718
# Image not found for Image_(1138).jpg, using blank image
# Image not found for Halal Memes (110).jpg, using blank image
# Epoch 10, Batch 380/1120, Loss: 0.1099
# Epoch 10, Batch 390/1120, Loss: 0.3733
# Image not found for image_ (619).jpg, using blank image
# Epoch 10, Batch 400/1120, Loss: 0.2565
# Image not found for 16032.png, using blank image
# Image not found for Image_(3132).jpg, using blank image
# Epoch 10, Batch 410/1120, Loss: 0.0884
# Epoch 10, Batch 420/1120, Loss: 0.2850
# Image not found for 61872.png, using blank image
# Image not found for image_ (2343).jpg, using blank image
# Epoch 10, Batch 430/1120, Loss: 0.4830
# Image not found for image_ (3989).jpg, using blank image
# Image not found for ovodro_img (237).jpg, using blank image
# Image not found for 62913.png, using blank image
# Image not found for Image_(603).jpg, using blank image
# Image not found for 34196.png, using blank image
# Epoch 10, Batch 440/1120, Loss: 0.3350
# Epoch 10, Batch 450/1120, Loss: 0.4012
# Image not found for 34786.png, using blank image
# Image not found for 17230.png, using blank image
# Image not found for image_ (431).jpg, using blank image
# Epoch 10, Batch 460/1120, Loss: 0.2423
# Epoch 10, Batch 470/1120, Loss: 0.2407
# Image not found for Image_(3969).jpg, using blank image
# Image not found for Image_(2872).jpg, using blank image
# Epoch 10, Batch 480/1120, Loss: 0.6689
# Epoch 10, Batch 490/1120, Loss: 0.3077
# Epoch 10, Batch 500/1120, Loss: 0.2823
# Image not found for Bangla Thug Life (372).jpg, using blank image
# Epoch 10, Batch 510/1120, Loss: 0.2098
# Image not found for 01379.png, using blank image
# Image not found for Image_(2869).jpg, using blank image
# Epoch 10, Batch 520/1120, Loss: 0.1868
# Image not found for ovodro_img (260).jpg, using blank image
# Image not found for Image_(2113).jpg, using blank image
# Epoch 10, Batch 530/1120, Loss: 0.3218
# Image not found for 72386.png, using blank image
# Image not found for Image_(4763).jpg, using blank image
# Image not found for Image_(3369).jpg, using blank image
# Image not found for Image_(1714).jpg, using blank image
# Epoch 10, Batch 540/1120, Loss: 0.2467
# Image not found for 62571.png, using blank image
# Epoch 10, Batch 550/1120, Loss: 0.4243
# Image not found for KAM (302).jpg, using blank image
# Image not found for 86914.png, using blank image
# Image not found for meme_133.png, using blank image
# Epoch 10, Batch 560/1120, Loss: 0.1840
# Image not found for Image_(4798).jpg, using blank image
# Image not found for 64390.png, using blank image
# Epoch 10, Batch 570/1120, Loss: 0.3849
# Image not found for Image_(3516).jpg, using blank image
# Epoch 10, Batch 580/1120, Loss: 0.4044
# Epoch 10, Batch 590/1120, Loss: 0.3567
# Image not found for Image_(633).jpg, using blank image
# Epoch 10, Batch 600/1120, Loss: 0.2650
# Image not found for image_ (1003).jpg, using blank image
# Image not found for Image_(4972).jpg, using blank image
# Image not found for Image_(2688).jpg, using blank image
# Epoch 10, Batch 610/1120, Loss: 0.5059
# Image not found for 59047.png, using blank image
# Epoch 10, Batch 620/1120, Loss: 0.2611
# Image not found for Image_(2532).jpg, using blank image
# Image not found for 35074.png, using blank image
# Image not found for 29841.png, using blank image
# Epoch 10, Batch 630/1120, Loss: 0.2834
# Image not found for 04361.png, using blank image
# Image not found for 35869.png, using blank image
# Epoch 10, Batch 640/1120, Loss: 0.5182
# Image not found for Image_(2152).jpg, using blank image
# Image not found for Image_(1505).jpg, using blank image
# Epoch 10, Batch 650/1120, Loss: 0.2653
# Image not found for eng319.png, using blank image
# Epoch 10, Batch 660/1120, Loss: 0.2529
# Epoch 10, Batch 670/1120, Loss: 0.6124
# Epoch 10, Batch 680/1120, Loss: 0.3036
# Epoch 10, Batch 690/1120, Loss: 0.7513
# Image not found for ovodro_img (229).jpg, using blank image
# Image not found for 25768.png, using blank image
# Epoch 10, Batch 700/1120, Loss: 0.4496
# Image not found for tangaila (233).jpg, using blank image
# Epoch 10, Batch 710/1120, Loss: 0.4480
# Image not found for 61280.png, using blank image
# Image not found for image_ (2342).jpg, using blank image
# Image not found for rhea16.png, using blank image
# Image not found for image_ (3534).jpg, using blank image
# Epoch 10, Batch 720/1120, Loss: 0.3973
# Image not found for 29430.png, using blank image
# Image not found for 48790.png, using blank image
# Epoch 10, Batch 730/1120, Loss: 0.2855
# Image not found for bangla-gag (31).jpg, using blank image
# Image not found for image_ (1481).jpg, using blank image
# Epoch 10, Batch 740/1120, Loss: 0.4723
# Image not found for Image_(5940).jpg, using blank image
# Image not found for 51367.png, using blank image
# Epoch 10, Batch 750/1120, Loss: 0.1836
# Image not found for 28617.png, using blank image
# Epoch 10, Batch 760/1120, Loss: 0.4627
# Epoch 10, Batch 770/1120, Loss: 0.3628
# Image not found for 01465.png, using blank image
# Image not found for image_ (3437).jpg, using blank image
# Image not found for image_ (1486).jpg, using blank image
# Epoch 10, Batch 780/1120, Loss: 0.1987
# Image not found for 36842.png, using blank image
# Epoch 10, Batch 790/1120, Loss: 0.3025
# Image not found for 76098.png, using blank image
# Epoch 10, Batch 800/1120, Loss: 0.2004
# Image not found for 41830.png, using blank image
# Epoch 10, Batch 810/1120, Loss: 0.3027
# Image not found for 52780.png, using blank image
# Image not found for Image_(1429).jpg, using blank image
# Image not found for 64705.png, using blank image
# Epoch 10, Batch 820/1120, Loss: 0.3341
# Epoch 10, Batch 830/1120, Loss: 0.1457
# Image not found for 45037.png, using blank image
# Image not found for image_ (3511).jpg, using blank image
# Epoch 10, Batch 840/1120, Loss: 0.2134
# Epoch 10, Batch 850/1120, Loss: 0.3352
# Image not found for 65273.png, using blank image
# Image not found for 78459.png, using blank image
# Image not found for 27803.png, using blank image
# Image not found for 34862.png, using blank image
# Epoch 10, Batch 860/1120, Loss: 0.3416
# Image not found for image_ (1405).jpg, using blank image
# Image not found for image_ (3672).jpg, using blank image
# Image not found for bamboo-vaiya (247).jpg, using blank image
# Epoch 10, Batch 870/1120, Loss: 0.3830
# Epoch 10, Batch 880/1120, Loss: 0.5136
# Epoch 10, Batch 890/1120, Loss: 0.1646
# Image not found for Image_(2355).jpg, using blank image
# Epoch 10, Batch 900/1120, Loss: 0.1902
# Image not found for 87392.png, using blank image
# Image not found for Image_(3180).jpg, using blank image
# Epoch 10, Batch 910/1120, Loss: 0.5875
# Image not found for bamboo-vaiya (274).jpg, using blank image
# Epoch 10, Batch 920/1120, Loss: 0.5274
# Image not found for 37615.png, using blank image
# Image not found for image_ (805).jpg, using blank image
# Epoch 10, Batch 930/1120, Loss: 0.3272
# Image not found for 50784.png, using blank image
# Image not found for bamboo-vaiya (94).jpg, using blank image
# Epoch 10, Batch 940/1120, Loss: 0.4298
# Image not found for gay108.png, using blank image
# Image not found for ovodro_img (541).jpg, using blank image
# Image not found for Image_(2698).jpg, using blank image
# Epoch 10, Batch 950/1120, Loss: 0.4339
# Epoch 10, Batch 960/1120, Loss: 0.3191
# Image not found for Image_(1287).jpg, using blank image
# Epoch 10, Batch 970/1120, Loss: 0.3580
# Image not found for 14092.png, using blank image
# Image not found for Image_(1080).jpg, using blank image
# Epoch 10, Batch 980/1120, Loss: 0.6754
# Image not found for meme_577.png, using blank image
# Image not found for 10673.png, using blank image
# Image not found for image_ (1401).jpg, using blank image
# Epoch 10, Batch 990/1120, Loss: 0.2518
# Epoch 10, Batch 1000/1120, Loss: 0.3060
# Image not found for Image_(5700).jpg, using blank image
# Image not found for Image_(2082).jpg, using blank image
# Epoch 10, Batch 1010/1120, Loss: 0.4090
# Image not found for KAM (193).jpg, using blank image
# Image not found for image_ (331).jpg, using blank image
# Epoch 10, Batch 1020/1120, Loss: 0.2275
# Image not found for image_ (1138).jpg, using blank image
# Image not found for image_ (2854).jpg, using blank image
# Epoch 10, Batch 1030/1120, Loss: 0.2202
# Image not found for KAM (519).jpg, using blank image
# Epoch 10, Batch 1040/1120, Loss: 0.3671
# Image not found for eng183.png, using blank image
# Epoch 10, Batch 1050/1120, Loss: 0.1823
# Image not found for Image_(5213).jpg, using blank image
# Image not found for Image_(2804).jpg, using blank image
# Epoch 10, Batch 1060/1120, Loss: 0.4024
# Image not found for Image_(1250).jpg, using blank image
# Image not found for image_ (3923).jpg, using blank image
# Epoch 10, Batch 1070/1120, Loss: 0.5927
# Image not found for Image_(3748).jpg, using blank image
# Image not found for 40752.png, using blank image
# Image not found for image_ (3171).jpg, using blank image
# Epoch 10, Batch 1080/1120, Loss: 0.4517
# Image not found for Image_(5249).jpg, using blank image
# Image not found for 28397.png, using blank image
# Epoch 10, Batch 1090/1120, Loss: 0.2430
# Image not found for 28076.png, using blank image
# Image not found for 72035.png, using blank image
# Image not found for 96420.png, using blank image
# Epoch 10, Batch 1100/1120, Loss: 0.4906
# Image not found for 01763.png, using blank image
# Epoch 10, Batch 1110/1120, Loss: 0.3262
# Epoch 10, Batch 1120/1120, Loss: 0.2312
# Image not found for 21096.png, using blank image
# Image not found for Image_(622).jpg, using blank image
# Image not found for image_ (3294).jpg, using blank image
# Image not found for Image_(3591).jpg, using blank image
# Image not found for image_ (2869).jpg, using blank image
# Image not found for Image_(2315).jpg, using blank image
# Image not found for Image_(1643).jpg, using blank image
# Image not found for Image_(2963).jpg, using blank image
# Image not found for 45029.png, using blank image
# Image not found for Image_(352).jpg, using blank image
# Image not found for image_ (3799).jpg, using blank image
# Image not found for image_ (326).jpg, using blank image
# Image not found for 83960.png, using blank image
# Image not found for meme_175.png, using blank image
# Image not found for 60741.png, using blank image
# Image not found for image_ (2257).jpg, using blank image
# Image not found for chosha (78).jpg, using blank image
# Image not found for bangla-troll (27).jpg, using blank image
# Image not found for 18497.png, using blank image
# Image not found for 62197.png, using blank image
# Image not found for eng165.png, using blank image
# Image not found for 50683.png, using blank image
# Image not found for 19567.png, using blank image
# Image not found for KAM (32).jpg, using blank image
# Image not found for 39612.png, using blank image
# Image not found for Image_(1796).jpg, using blank image
# Image not found for image_ (1177).jpg, using blank image
# Image not found for bamboo-vaiya (379).jpg, using blank image
# Image not found for Image_(3475).jpg, using blank image
# Image not found for 41087.png, using blank image
# Image not found for 62703.png, using blank image
# Image not found for Image_(189).jpg, using blank image
# Image not found for 95712.png, using blank image
# Image not found for image_ (1949).jpg, using blank image
# Image not found for Image_(497).jpg, using blank image
# Image not found for 54976.png, using blank image
# Image not found for Image_(3029).jpg, using blank image
# Image not found for ovodro_img (494).jpg, using blank image
# Image not found for image_ (3777).jpg, using blank image
# Epoch 10/10, Train Loss: 0.3311, Train Acc: 0.8441, Valid Loss: 585.6432, Valid Acc: 0.6792
# Saved model with validation loss: 585.6432
# /tmp/ipykernel_129/2195608675.py:48: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_xception_bert_model.pth'))
# Evaluating model on test set...
# Image not found for image_ (2994).jpg, using blank image
# Image not found for meme_380.png, using blank image
# Image not found for 18432.png, using blank image
# Image not found for 68951.png, using blank image
# Image not found for meme_208.png, using blank image
# Image not found for Image_(817).jpg, using blank image
# Image not found for Image_(2832).jpg, using blank image
# Image not found for 47901.png, using blank image
# Image not found for 97831.png, using blank image
# Image not found for Image_(1858).jpg, using blank image
# Image not found for 79386.png, using blank image
# Image not found for 89732.png, using blank image
# Image not found for 36578.png, using blank image
# Image not found for Image_(5599).jpg, using blank image
# Image not found for 09731.png, using blank image
# Image not found for 80734.png, using blank image
# Image not found for 51746.png, using blank image
# Image not found for image_ (2190).jpg, using blank image
# Image not found for image_ (111).jpg, using blank image
# Image not found for image_ (472).jpg, using blank image
# Image not found for 47326.png, using blank image
# Image not found for Image_(3343).jpg, using blank image
# Image not found for image_ (3499).jpg, using blank image
# Image not found for image_ (3956).jpg, using blank image
# Image not found for Bangla Thug Life (172).jpg, using blank image
# Image not found for Halal Memes (41).jpg, using blank image
# Image not found for Image_(4508).jpg, using blank image
# Image not found for 14086.png, using blank image
# Image not found for 59178.png, using blank image
# Image not found for chosha (31).jpg, using blank image
# Image not found for Image_(2107).jpg, using blank image
# Image not found for 71249.png, using blank image
# Image not found for Image_(1634).jpg, using blank image
# Image not found for 97685.png, using blank image
# Image not found for tangaila (110).jpg, using blank image
# Image not found for Image_(4677).jpg, using blank image
# Image not found for Image_(1569).jpg, using blank image
# Image not found for image_ (2789).jpg, using blank image
# Image not found for image_ (2961).jpg, using blank image
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# Test Accuracy: 0.6792
#
# Confusion Matrix:
# [[   0 1232]
#  [   0 2608]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Harmful       0.00      0.00      0.00      1232
#      Harmful       0.68      1.00      0.81      2608
#
#     accuracy                           0.68      3840
#    macro avg       0.34      0.50      0.40      3840
# weighted avg       0.46      0.68      0.55      3840
# xception model training and evaluation complete!
