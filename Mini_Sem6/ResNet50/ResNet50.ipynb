# %%
import os
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, models
from PIL import Image
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns
from transformers import BertTokenizer, BertModel
import re
import glob

# Set device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Load dataset
df = pd.read_csv('/kaggle/input/multilingual-meme-datasets/final_datasets.csv')
print(f"Dataset loaded with shape: {df.shape}")

# Image directory
image_dir = "/kaggle/input/multilingual-meme-datasets/datasets/datasets"

def create_image_mapping(dataframe, image_directory):
    """
    Create a mapping between dataset 'name' column and actual image filenames in the directory.
    This handles the case where image filenames might have different formats.
    """
    # Get all image files in the directory
    image_files = glob.glob(os.path.join(image_directory, '*'))
    image_mapping = {}
    
    # Create a set of all available image filenames (without path)
    available_images = {os.path.basename(f) for f in image_files}
    print(f"Found {len(available_images)} images in directory")
    
    # Print some sample images to understand the naming pattern
    print("Sample image filenames:", list(available_images)[:5])
    
    # Print some sample names from the dataset
    print("Sample names from dataset:", dataframe['name'].iloc[:5].tolist())
    
    # Method 1: Exact match
    for name in dataframe['name'].unique():
        if name in available_images:
            image_mapping[name] = name
    
    # Method 2: Check if the id is part of the filename
    unmapped_names = set(dataframe['name']) - set(image_mapping.keys())
    for name in unmapped_names:
        # Extract ID from name (assuming name has some ID pattern)
        id_match = re.search(r'\d+', name)
        if id_match:
            id_value = id_match.group()
            # Look for files containing this ID
            matching_files = [f for f in available_images if id_value in f]
            if matching_files:
                image_mapping[name] = matching_files[0]
    
    # Method 3: Try matching using 'ids' or 'id' column if available
    if 'ids' in dataframe.columns or 'id' in dataframe.columns:
        id_col = 'ids' if 'ids' in dataframe.columns else 'id'
        id_to_name = dict(zip(dataframe[id_col], dataframe['name']))
        
        for id_value, name in id_to_name.items():
            if name not in image_mapping:
                # Look for files containing this ID
                matching_files = [f for f in available_images if str(id_value) in f]
                if matching_files:
                    image_mapping[name] = matching_files[0]
    
    print(f"Successfully mapped {len(image_mapping)} out of {len(dataframe['name'].unique())} unique names")
    return image_mapping

# Custom dataset class with image mapping for ResNet50
class HarmfulContentDataset(Dataset):
    def __init__(self, dataframe, image_dir, tokenizer, image_mapping=None, max_len=128):
        self.dataframe = dataframe
        self.image_dir = image_dir
        self.tokenizer = tokenizer
        self.max_len = max_len
        self.image_mapping = image_mapping or {}
        
        # Create a default blank image to use when an image is not found
        self.blank_image = Image.new('RGB', (224, 224), color='white')
        
        # Image transformation for ResNet50
        self.transform = transforms.Compose([
            transforms.Resize((224, 224)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])
    
    def __len__(self):
        return len(self.dataframe)
    
    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        
        # Text features
        text_features = f"{row['gender']} {row['age']} {row['age_bucket']} {row['dominant_emotion']} {row['dominant_race']} {row['translated_text']}"
        
        # Tokenize text
        encoding = self.tokenizer.encode_plus(
            text_features,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            truncation=True,
            return_attention_mask=True,
            return_tensors='pt',
        )
        
        # Image processing
        try:
            # Get the correct image filename using the mapping
            image_filename = self.image_mapping.get(row['name'], row['name'])
            image_path = os.path.join(self.image_dir, image_filename)
            
            # Check if the file exists
            if os.path.exists(image_path):
                image = Image.open(image_path).convert('RGB')
            else:
                # Try alternate approach: check if the file exists with different extensions
                base_name = os.path.splitext(image_path)[0]
                for ext in ['.jpg', '.jpeg', '.png', '.gif']:
                    alt_path = base_name + ext
                    if os.path.exists(alt_path):
                        image = Image.open(alt_path).convert('RGB')
                        break
                else:
                    # If still not found, use blank image
                    image = self.blank_image
                    if idx % 100 == 0:  # Limit logging to avoid flooding
                        print(f"Image not found for {row['name']}, using blank image")
            
            # Apply transformations for ResNet50
            image_tensor = self.transform(image)
            
        except Exception as e:
            if idx % 100 == 0:  # Limit logging
                print(f"Error processing image for {row['name']}: {e}")
            # Create blank image features
            image_tensor = torch.zeros((3, 224, 224))
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'image': image_tensor,
            'labels': torch.tensor(row['label'], dtype=torch.long)
        }

# Custom model class using ResNet50 + BERT
class ResNet50BertClassifier(nn.Module):
    def __init__(self, num_classes=2):
        super(ResNet50BertClassifier, self).__init__()
        
        # Load pretrained ResNet50
        self.resnet = models.resnet50(pretrained=True)
        
        # Remove the final fully connected layer
        self.resnet = nn.Sequential(*list(self.resnet.children())[:-1])
        
        # Load pre-trained BERT
        self.bert = BertModel.from_pretrained("bert-base-multilingual-cased")
        
        # Freeze ResNet weights
        for param in self.resnet.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of ResNet
        for param in list(self.resnet.children())[-2:]:
            for p in param.parameters():
                p.requires_grad = True
        
        # Freeze BERT weights
        for param in self.bert.parameters():
            param.requires_grad = False
            
        # Unfreeze the last few layers of BERT
        for param in self.bert.encoder.layer[-2:].parameters():
            param.requires_grad = True
        
        # Dimensionality of ResNet and BERT embeddings
        resnet_hidden_size = 2048  # ResNet50 output dimension
        bert_hidden_size = self.bert.config.hidden_size
        
        # Enhanced classification head
        self.classifier = nn.Sequential(
            nn.Linear(resnet_hidden_size + bert_hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(256, num_classes)
        )
        
    def forward(self, input_ids, attention_mask, image):
        # Process image with ResNet50
        image_features = self.resnet(image)
        image_features = image_features.view(image_features.size(0), -1)  # Flatten the features
        
        # Process text with BERT
        bert_outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        bert_embeddings = bert_outputs.last_hidden_state[:, 0, :]  # CLS token
        
        # Concatenate image and text features
        combined_embeddings = torch.cat((image_features, bert_embeddings), dim=1)
        
        # Classification
        logits = self.classifier(combined_embeddings)
        
        return logits

# Training function
def train_model(model, train_loader, valid_loader, criterion, optimizer, scheduler=None, num_epochs=10):
    train_losses = []
    valid_losses = []
    train_accuracies = []
    valid_accuracies = []
    
    best_valid_loss = float('inf')
    
    for epoch in range(num_epochs):
        # Training
        model.train()
        running_loss = 0.0
        correct_train = 0
        total_train = 0
        
        for batch_idx, batch in enumerate(train_loader):
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            optimizer.zero_grad()
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            loss = criterion(outputs, labels)
            
            loss.backward()
            optimizer.step()
            
            running_loss += loss.item()
            
            _, predicted = torch.max(outputs.data, 1)
            total_train += labels.size(0)
            correct_train += (predicted == labels).sum().item()
            
            # Print batch progress
            if (batch_idx + 1) % 10 == 0:
                print(f'Epoch {epoch+1}, Batch {batch_idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
        
        train_loss = running_loss / len(train_loader)
        train_accuracy = correct_train / total_train
        train_losses.append(train_loss)
        train_accuracies.append(train_accuracy)
        
        # Validation
        model.eval()
        running_valid_loss = 0.0
        correct_valid = 0
        total_valid = 0
        
        with torch.no_grad():
            for batch in valid_loader:
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                images = batch['image'].to(device)
                labels = batch['labels'].to(device)
                
                outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
                loss = criterion(outputs, labels)
                
                running_valid_loss += loss.item()
                
                _, predicted = torch.max(outputs.data, 1)
                total_valid += labels.size(0)
                correct_valid += (predicted == labels).sum().item()
        
        valid_loss = running_valid_loss / len(valid_loader)
        valid_accuracy = correct_valid / total_valid
        valid_losses.append(valid_loss)
        valid_accuracies.append(valid_accuracy)
        
        print(f'Epoch {epoch+1}/{num_epochs}, '
              f'Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, '
              f'Valid Loss: {valid_loss:.4f}, Valid Acc: {valid_accuracy:.4f}')
        
        # Update scheduler if provided
        if scheduler is not None:
            scheduler.step(valid_loss)
        
        # Save best model
        if valid_loss < best_valid_loss:
            best_valid_loss = valid_loss
            torch.save(model.state_dict(), 'best_resnet50_bert_model.pth')
            print(f'Saved model with validation loss: {valid_loss:.4f}')
    
    return train_losses, valid_losses, train_accuracies, valid_accuracies

# Function for evaluation and metrics
def evaluate_model(model, test_loader):
    model.eval()
    y_true = []
    y_pred = []
    
    with torch.no_grad():
        for batch in test_loader:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            images = batch['image'].to(device)
            labels = batch['labels'].to(device)
            
            outputs = model(input_ids=input_ids, attention_mask=attention_mask, image=images)
            _, predicted = torch.max(outputs.data, 1)
            
            y_true.extend(labels.cpu().numpy())
            y_pred.extend(predicted.cpu().numpy())
    
    # Calculate metrics
    accuracy = accuracy_score(y_true, y_pred)
    conf_matrix = confusion_matrix(y_true, y_pred)
    class_report = classification_report(y_true, y_pred, target_names=['Non-Harmful', 'Harmful'])
    
    print(f'Test Accuracy: {accuracy:.4f}')
    print('\nConfusion Matrix:')
    print(conf_matrix)
    print('\nClassification Report:')
    print(class_report)
    
    # Plot confusion matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['Non-Harmful', 'Harmful'], 
                yticklabels=['Non-Harmful', 'Harmful'])
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.savefig('resnet50_confusion_matrix.png')
    plt.show()
    
    return accuracy, conf_matrix, class_report

# Function to plot training curves
def plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies):
    # Plot loss
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(valid_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training vs Validation Loss')
    plt.legend()
    
    # Plot accuracy
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(valid_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training vs Validation Accuracy')
    plt.legend()
    
    plt.tight_layout()
    plt.savefig('resnet50_training_curves.png')
    plt.show()

# Main execution
def main():
    # Initialize tokenizer for BERT
    tokenizer = BertTokenizer.from_pretrained("bert-base-multilingual-cased")
    
    # Inspect dataset and image directory
    image_files = inspect_dataset(df, image_dir)
    
    # Create mapping between dataset names and image filenames
    image_mapping = create_image_mapping(df, image_dir)
    
    # Split dataset
    train_df, temp_df = train_test_split(df, test_size=0.3, random_state=42, stratify=df['label'])
    valid_df, test_df = train_test_split(temp_df, test_size=0.5, random_state=42, stratify=temp_df['label'])
    
    print(f"Train set: {len(train_df)}, Validation set: {len(valid_df)}, Test set: {len(test_df)}")
    
    # Create datasets with image mapping
    train_dataset = HarmfulContentDataset(train_df, image_dir, tokenizer, image_mapping)
    valid_dataset = HarmfulContentDataset(valid_df, image_dir, tokenizer, image_mapping)
    test_dataset = HarmfulContentDataset(test_df, image_dir, tokenizer, image_mapping)
    
    # Create dataloaders
    batch_size = 16  # ResNet50 might allow for larger batch sizes compared to ViT
    train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, num_workers=2)
    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=2)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=2)
    
    # Initialize model with ResNet50
    model = ResNet50BertClassifier(num_classes=2).to(device)
    
    # Loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.AdamW(filter(lambda p: p.requires_grad, model.parameters()), lr=2e-5)
    
    # Learning rate scheduler
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=2, verbose=True)
    
    # Train model
    print("Starting training...")
    train_losses, valid_losses, train_accuracies, valid_accuracies = train_model(
        model, train_loader, valid_loader, criterion, optimizer, scheduler, num_epochs=10
    )
    
    # Plot training curves
    plot_training_curves(train_losses, valid_losses, train_accuracies, valid_accuracies)
    
    # Load best model for evaluation
    model.load_state_dict(torch.load('best_resnet50_bert_model.pth'))
    
    # Evaluate model
    print("\nEvaluating model on test set...")
    accuracy, conf_matrix, class_report = evaluate_model(model, test_loader)
    
    # Save final model with metadata
    torch.save({
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': optimizer.state_dict(),
        'accuracy': accuracy,
        'conf_matrix': conf_matrix,
        'class_report': class_report,
    }, 'resnet50_harmful_content_classifier.pth')
    
    print("ResNet50 model training and evaluation complete!")

# Helper function to inspect dataset
def inspect_dataset(df, image_dir):
    """
    Inspects the dataset and the image directory to understand the structure.
    """
    print("\n=== Dataset Inspection ===")
    print(f"Dataset columns: {df.columns.tolist()}")
    print(f"Number of rows: {len(df)}")
    print(f"Label distribution: {df['label'].value_counts().to_dict()}")
    
    # Check if image directory exists
    if not os.path.exists(image_dir):
        print(f"WARNING: Image directory does not exist: {image_dir}")
        return
    
    # Count image files
    image_files = [f for f in os.listdir(image_dir) if os.path.isfile(os.path.join(image_dir, f)) and 
                   f.lower().endswith(('.png', '.jpg', '.jpeg', '.gif', '.bmp'))]
    
    print(f"Number of image files in directory: {len(image_files)}")
    if len(image_files) > 0:
        print(f"Sample image filenames: {image_files[:5]}")
    
    # Check name column format
    print("\nSample names from dataset:")
    print(df['name'].head(5).tolist())
    
    # Check if any dataset names exactly match image filenames
    matching_names = [name for name in df['name'].unique() if name in image_files]
    print(f"Number of exact matches between 'name' column and image filenames: {len(matching_names)}")
    
    # Check if IDs are in the name column
    if 'id' in df.columns or 'ids' in df.columns:
        id_col = 'ids' if 'ids' in df.columns else 'id'
        print(f"\nSample values from '{id_col}' column:")
        print(df[id_col].head(5).tolist())
        
        # Check if IDs are in image filenames
        sample_ids = df[id_col].astype(str).head(5).tolist()
        for id_val in sample_ids:
            matches = [f for f in image_files if id_val in f]
            if matches:
                print(f"Found matches for ID {id_val}: {matches[:2]}")
                
    return image_files

if __name__ == "__main__":
    main()
# Out:
# 2025-04-16 07:18:34.594255: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744787914.789682      31 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744787914.846008      31 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Using device: cuda:0
# Dataset loaded with shape: (25600, 11)
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.96M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/625 [00:00<?, ?B/s]
# === Dataset Inspection ===
# Dataset columns: ['ids', 'name', 'text', 'label', 'id', 'gender', 'age', 'age_bucket', 'dominant_emotion', 'dominant_race', 'translated_text']
# Number of rows: 25600
# Label distribution: {1: 17388, 0: 8212}
# Number of image files in directory: 25716
# Sample image filenames: ['eng476.png', 'meme_184.png', 'tangaila (166).jpg', 'Image- (178).jpg', 'Image- (2026).jpg']
#
# Sample names from dataset:
# ['tangaila (1).jpg', 'tangaila (2).jpg', 'tangaila (3).jpg', 'tangaila (4).jpg', 'tangaila (5).jpg']
# Number of exact matches between 'name' column and image filenames: 18670
#
# Sample values from 'ids' column:
# [1, 2, 3, 4, 5]
# Found matches for ID 1: ['meme_184.png', 'tangaila (166).jpg']
# Found matches for ID 2: ['Image- (2026).jpg', 'image_ (2682).jpg']
# Found matches for ID 3: ['Bangla Thug Life (374).jpg', '37825.png']
# Found matches for ID 4: ['eng476.png', 'meme_184.png']
# Found matches for ID 5: ['52691.png', '37825.png']
# Found 25716 images in directory
# Sample image filenames: ['bamboo-vaiya (296).jpg', 'Image- (4309).jpg', 'bamboo-vaiya (536).jpg', 'Image- (3049).jpg', 'image_ (2453).jpg']
# Sample names from dataset: ['tangaila (1).jpg', 'tangaila (2).jpg', 'tangaila (3).jpg', 'tangaila (4).jpg', 'tangaila (5).jpg']
# Successfully mapped 25432 out of 25432 unique names
# Train set: 17920, Validation set: 3840, Test set: 3840
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
# 100%|██████████| 97.8M/97.8M [00:01<00:00, 88.7MB/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/714M [00:00<?, ?B/s]
# Starting training...
# Epoch 1, Batch 10/1120, Loss: 0.6628
# Epoch 1, Batch 20/1120, Loss: 0.5663
# Epoch 1, Batch 30/1120, Loss: 0.6121
# Epoch 1, Batch 40/1120, Loss: 0.5379
# Epoch 1, Batch 50/1120, Loss: 0.6076
# Epoch 1, Batch 60/1120, Loss: 0.6419
# Epoch 1, Batch 70/1120, Loss: 0.5165
# Epoch 1, Batch 80/1120, Loss: 0.5377
# Epoch 1, Batch 90/1120, Loss: 0.5594
# Epoch 1, Batch 100/1120, Loss: 0.6240
# Epoch 1, Batch 110/1120, Loss: 0.5579
# Epoch 1, Batch 120/1120, Loss: 0.4360
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 1, Batch 130/1120, Loss: 0.2848
# Epoch 1, Batch 140/1120, Loss: 0.4738
# Epoch 1, Batch 150/1120, Loss: 0.5656
# Epoch 1, Batch 160/1120, Loss: 0.4529
# Epoch 1, Batch 170/1120, Loss: 0.3984
# Epoch 1, Batch 180/1120, Loss: 0.4025
# Epoch 1, Batch 190/1120, Loss: 0.5238
# Epoch 1, Batch 200/1120, Loss: 0.5577
# Epoch 1, Batch 210/1120, Loss: 0.3242
# Epoch 1, Batch 220/1120, Loss: 0.4343
# Epoch 1, Batch 230/1120, Loss: 0.4473
# Epoch 1, Batch 240/1120, Loss: 0.6870
# Epoch 1, Batch 250/1120, Loss: 0.4363
# Epoch 1, Batch 260/1120, Loss: 0.4923
# Epoch 1, Batch 270/1120, Loss: 0.3019
# Epoch 1, Batch 280/1120, Loss: 0.2948
# Epoch 1, Batch 290/1120, Loss: 0.3071
# Epoch 1, Batch 300/1120, Loss: 0.3598
# Epoch 1, Batch 310/1120, Loss: 0.3662
# Epoch 1, Batch 320/1120, Loss: 0.6314
# Epoch 1, Batch 330/1120, Loss: 0.3703
# Epoch 1, Batch 340/1120, Loss: 0.4099
# Epoch 1, Batch 350/1120, Loss: 0.5748
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 3, Batch 260/1120, Loss: 0.1806
# Epoch 3, Batch 270/1120, Loss: 0.1380
# Epoch 3, Batch 280/1120, Loss: 0.1043
# Epoch 3, Batch 290/1120, Loss: 0.1149
# Epoch 3, Batch 300/1120, Loss: 0.6253
# Epoch 3, Batch 310/1120, Loss: 0.3126
# Epoch 3, Batch 320/1120, Loss: 0.1281
# Epoch 3, Batch 330/1120, Loss: 0.3219
# Epoch 3, Batch 340/1120, Loss: 0.2798
# Epoch 3, Batch 350/1120, Loss: 0.2498
# Epoch 3, Batch 360/1120, Loss: 0.1539
# Epoch 3, Batch 370/1120, Loss: 0.3189
# Epoch 3, Batch 380/1120, Loss: 0.4568
# Epoch 3, Batch 390/1120, Loss: 0.4579
# Epoch 3, Batch 400/1120, Loss: 0.4512
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 3, Batch 410/1120, Loss: 0.4838
# Epoch 3, Batch 420/1120, Loss: 0.2737
# Epoch 3, Batch 430/1120, Loss: 0.2162
# Epoch 3, Batch 440/1120, Loss: 0.2017
# Epoch 3, Batch 450/1120, Loss: 0.3364
# Epoch 3, Batch 460/1120, Loss: 0.3331
# Epoch 3, Batch 470/1120, Loss: 0.3865
# Epoch 3, Batch 480/1120, Loss: 0.1707
# Epoch 3, Batch 490/1120, Loss: 0.1198
# Epoch 3, Batch 500/1120, Loss: 0.1190
# Epoch 3, Batch 510/1120, Loss: 0.3122
# Epoch 3, Batch 520/1120, Loss: 0.2295
# Epoch 3, Batch 530/1120, Loss: 0.3914
# Epoch 3, Batch 540/1120, Loss: 0.3373
# Epoch 3, Batch 550/1120, Loss: 0.1582
# Epoch 3, Batch 560/1120, Loss: 0.1296
# Epoch 3, Batch 570/1120, Loss: 0.1135
# Epoch 3, Batch 580/1120, Loss: 0.4247
# Epoch 3, Batch 590/1120, Loss: 0.1841
# Epoch 3, Batch 600/1120, Loss: 0.4592
# Epoch 3, Batch 610/1120, Loss: 0.4006
# Epoch 3, Batch 620/1120, Loss: 0.6084
# Epoch 3, Batch 630/1120, Loss: 0.2636
# Epoch 3, Batch 640/1120, Loss: 0.1197
# Epoch 3, Batch 650/1120, Loss: 0.2139
# Epoch 3, Batch 660/1120, Loss: 0.2409
# Epoch 3, Batch 670/1120, Loss: 0.1035
# Epoch 3, Batch 680/1120, Loss: 0.0926
# Epoch 3, Batch 690/1120, Loss: 0.3551
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 3, Batch 700/1120, Loss: 0.2695
# Epoch 3, Batch 710/1120, Loss: 0.1768
# Epoch 3, Batch 720/1120, Loss: 0.3333
# Epoch 3, Batch 730/1120, Loss: 0.2591
# Epoch 3, Batch 740/1120, Loss: 0.2289
# Epoch 3, Batch 750/1120, Loss: 0.5853
# Epoch 3, Batch 760/1120, Loss: 0.2430
# Epoch 3, Batch 770/1120, Loss: 0.3709
# Epoch 3, Batch 780/1120, Loss: 0.2121
# Epoch 3, Batch 790/1120, Loss: 0.3745
# Epoch 3, Batch 800/1120, Loss: 0.5091
# Epoch 3, Batch 810/1120, Loss: 0.3054
# Epoch 3, Batch 820/1120, Loss: 0.2121
# Epoch 3, Batch 830/1120, Loss: 0.3394
# Epoch 3, Batch 840/1120, Loss: 0.4077
# Epoch 3, Batch 850/1120, Loss: 0.1226
# Epoch 5, Batch 810/1120, Loss: 0.3456
# Epoch 5, Batch 820/1120, Loss: 0.1073
# Epoch 5, Batch 830/1120, Loss: 0.2947
# Epoch 5, Batch 840/1120, Loss: 0.1119
# Epoch 5, Batch 850/1120, Loss: 0.2325
# Epoch 5, Batch 860/1120, Loss: 0.2978
# Epoch 5, Batch 870/1120, Loss: 0.1952
# Epoch 5, Batch 880/1120, Loss: 0.3602
# Epoch 5, Batch 890/1120, Loss: 0.2013
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 5, Batch 900/1120, Loss: 0.0390
# Epoch 5, Batch 910/1120, Loss: 0.1054
# Epoch 5, Batch 920/1120, Loss: 0.0331
# Epoch 5, Batch 930/1120, Loss: 0.0790
# Epoch 5, Batch 940/1120, Loss: 0.0279
# Epoch 5, Batch 950/1120, Loss: 0.0301
# Epoch 5, Batch 960/1120, Loss: 0.0488
# Epoch 5, Batch 970/1120, Loss: 0.1619
# Epoch 5, Batch 980/1120, Loss: 0.0473
# Epoch 5, Batch 990/1120, Loss: 0.0281
# Epoch 5, Batch 1000/1120, Loss: 0.2835
# Epoch 5, Batch 1010/1120, Loss: 0.0663
# Epoch 5, Batch 1020/1120, Loss: 0.1287
# Epoch 5, Batch 1030/1120, Loss: 0.0815
# Epoch 5, Batch 1040/1120, Loss: 0.1587
# Epoch 5, Batch 1050/1120, Loss: 0.1012
# Epoch 5, Batch 1060/1120, Loss: 0.3076
# Epoch 5, Batch 1070/1120, Loss: 0.0981
# Epoch 5, Batch 1080/1120, Loss: 0.1468
# Epoch 5, Batch 1090/1120, Loss: 0.3482
# Epoch 5, Batch 1100/1120, Loss: 0.0140
# Epoch 5, Batch 1110/1120, Loss: 0.1407
# Epoch 5, Batch 1120/1120, Loss: 0.1704
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 5/10, Train Loss: 0.1317, Train Acc: 0.9509, Valid Loss: 0.7122, Valid Acc: 0.7781
# Epoch 6, Batch 10/1120, Loss: 0.0226
# Epoch 6, Batch 20/1120, Loss: 0.1279
# Epoch 6, Batch 30/1120, Loss: 0.0164
# Epoch 6, Batch 40/1120, Loss: 0.0887
# Epoch 6, Batch 50/1120, Loss: 0.0717
# Epoch 6, Batch 60/1120, Loss: 0.1468
# Epoch 6, Batch 70/1120, Loss: 0.0488
# Epoch 6, Batch 80/1120, Loss: 0.0083
# Epoch 6, Batch 90/1120, Loss: 0.0404
# Epoch 6, Batch 100/1120, Loss: 0.0130
# Epoch 6, Batch 110/1120, Loss: 0.0113
# Epoch 6, Batch 120/1120, Loss: 0.2171
# Epoch 6, Batch 130/1120, Loss: 0.0778
# Epoch 6, Batch 140/1120, Loss: 0.0098
# Epoch 6, Batch 150/1120, Loss: 0.2373
# Epoch 6, Batch 160/1120, Loss: 0.2662
# Epoch 6, Batch 170/1120, Loss: 0.2188
# Epoch 6, Batch 180/1120, Loss: 0.3793
# Epoch 6, Batch 190/1120, Loss: 0.1050
# Epoch 6, Batch 200/1120, Loss: 0.0296
# Epoch 6, Batch 210/1120, Loss: 0.0466
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 6, Batch 220/1120, Loss: 0.0480
# Epoch 6, Batch 230/1120, Loss: 0.0371
# Epoch 6, Batch 240/1120, Loss: 0.0747
# Epoch 6, Batch 250/1120, Loss: 0.0325
# Epoch 6, Batch 260/1120, Loss: 0.0362
# Epoch 6, Batch 270/1120, Loss: 0.2263
# Epoch 6, Batch 280/1120, Loss: 0.0529
# Epoch 6, Batch 290/1120, Loss: 0.0338
# Epoch 6, Batch 300/1120, Loss: 0.0330
# Epoch 6, Batch 310/1120, Loss: 0.0261
# Epoch 6, Batch 320/1120, Loss: 0.0080
# Epoch 6, Batch 330/1120, Loss: 0.0231
# Epoch 6, Batch 340/1120, Loss: 0.2105
# Epoch 6, Batch 350/1120, Loss: 0.0559
# Epoch 6, Batch 360/1120, Loss: 0.0222
# Epoch 6, Batch 370/1120, Loss: 0.0268
# Epoch 6, Batch 380/1120, Loss: 0.0278
# Epoch 6, Batch 390/1120, Loss: 0.0886
# Epoch 6, Batch 400/1120, Loss: 0.0271
# Epoch 6, Batch 410/1120, Loss: 0.0213
# Epoch 6, Batch 420/1120, Loss: 0.0442
# Epoch 6, Batch 430/1120, Loss: 0.0220
# Epoch 6, Batch 440/1120, Loss: 0.0113
# Epoch 6, Batch 450/1120, Loss: 0.0292
# Epoch 6, Batch 460/1120, Loss: 0.0601
# Epoch 6, Batch 470/1120, Loss: 0.1373
# Epoch 6, Batch 480/1120, Loss: 0.3739
# Epoch 6, Batch 490/1120, Loss: 0.0341
# Epoch 6, Batch 500/1120, Loss: 0.0077
# Epoch 6, Batch 510/1120, Loss: 0.0759
# Epoch 6, Batch 520/1120, Loss: 0.2033
# Epoch 6, Batch 530/1120, Loss: 0.0940
# Epoch 6, Batch 540/1120, Loss: 0.1557
# Epoch 6, Batch 550/1120, Loss: 0.0870
# Epoch 6, Batch 560/1120, Loss: 0.0069
# Epoch 6, Batch 570/1120, Loss: 0.1127
# Epoch 6, Batch 580/1120, Loss: 0.0131
# Epoch 6, Batch 590/1120, Loss: 0.0252
# Epoch 6, Batch 600/1120, Loss: 0.0086
# Epoch 6, Batch 610/1120, Loss: 0.0934
# Epoch 6, Batch 620/1120, Loss: 0.0052
# Epoch 6, Batch 630/1120, Loss: 0.0505
# Epoch 6, Batch 640/1120, Loss: 0.2183
# Epoch 6, Batch 650/1120, Loss: 0.0175
# Epoch 6, Batch 660/1120, Loss: 0.0727
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 6, Batch 670/1120, Loss: 0.1929
# Epoch 6, Batch 680/1120, Loss: 0.0174
# Epoch 6, Batch 690/1120, Loss: 0.0040
# Epoch 6, Batch 700/1120, Loss: 0.0273
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 6, Batch 710/1120, Loss: 0.0249
# Epoch 6, Batch 720/1120, Loss: 0.0418
# Epoch 6, Batch 730/1120, Loss: 0.0305
# Epoch 6, Batch 740/1120, Loss: 0.0103
# Epoch 6, Batch 750/1120, Loss: 0.0064
# Epoch 6, Batch 760/1120, Loss: 0.1439
# Epoch 6, Batch 770/1120, Loss: 0.0317
# Epoch 6, Batch 780/1120, Loss: 0.0448
# Epoch 6, Batch 790/1120, Loss: 0.1182
# Epoch 6, Batch 800/1120, Loss: 0.0269
# Epoch 6, Batch 810/1120, Loss: 0.1482
# Epoch 6, Batch 820/1120, Loss: 0.0334
# Epoch 6, Batch 830/1120, Loss: 0.0222
# Epoch 6, Batch 840/1120, Loss: 0.0210
# Epoch 6, Batch 850/1120, Loss: 0.0871
# Epoch 6, Batch 860/1120, Loss: 0.4189
# Epoch 6, Batch 870/1120, Loss: 0.2417
# Epoch 6, Batch 880/1120, Loss: 0.0063
# Epoch 6, Batch 890/1120, Loss: 0.3075
# Epoch 6, Batch 900/1120, Loss: 0.2576
# Epoch 6, Batch 910/1120, Loss: 0.1544
# Epoch 6, Batch 920/1120, Loss: 0.1132
# Epoch 6, Batch 930/1120, Loss: 0.0239
# Epoch 6, Batch 940/1120, Loss: 0.3027
# Epoch 6, Batch 950/1120, Loss: 0.0133
# Epoch 6, Batch 960/1120, Loss: 0.1077
# Epoch 6, Batch 970/1120, Loss: 0.0853
# Epoch 6, Batch 980/1120, Loss: 0.0359
# Epoch 6, Batch 990/1120, Loss: 0.0567
# Epoch 6, Batch 1000/1120, Loss: 0.0193
# Epoch 6, Batch 1010/1120, Loss: 0.0821
# Epoch 6, Batch 1020/1120, Loss: 0.0065
# Epoch 6, Batch 1030/1120, Loss: 0.2280
# Epoch 6, Batch 1040/1120, Loss: 0.1247
# Epoch 6, Batch 1050/1120, Loss: 0.0158
# Epoch 6, Batch 1060/1120, Loss: 0.5388
# Epoch 6, Batch 1070/1120, Loss: 0.0197
# Epoch 6, Batch 1080/1120, Loss: 0.0939
# Epoch 6, Batch 1090/1120, Loss: 0.2356
# Epoch 6, Batch 1100/1120, Loss: 0.0255
# Epoch 6, Batch 1110/1120, Loss: 0.3245
# Epoch 6, Batch 1120/1120, Loss: 0.4014
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 6/10, Train Loss: 0.0810, Train Acc: 0.9712, Valid Loss: 0.8081, Valid Acc: 0.7786
# Epoch 7, Batch 10/1120, Loss: 0.1996
# Epoch 7, Batch 20/1120, Loss: 0.0129
# Epoch 7, Batch 30/1120, Loss: 0.0180
# Epoch 7, Batch 40/1120, Loss: 0.0099
# Epoch 7, Batch 50/1120, Loss: 0.1259
# Epoch 7, Batch 60/1120, Loss: 0.1322
# Epoch 7, Batch 70/1120, Loss: 0.0141
# Epoch 7, Batch 80/1120, Loss: 0.0123
# Epoch 7, Batch 90/1120, Loss: 0.0646
# Epoch 7, Batch 100/1120, Loss: 0.0354
# Epoch 7, Batch 110/1120, Loss: 0.0198
# Epoch 7, Batch 120/1120, Loss: 0.0252
# Epoch 7, Batch 130/1120, Loss: 0.3553
# Epoch 7, Batch 140/1120, Loss: 0.0128
# Epoch 7, Batch 150/1120, Loss: 0.0698
# Epoch 7, Batch 160/1120, Loss: 0.0072
# Epoch 7, Batch 170/1120, Loss: 0.1848
# Epoch 7, Batch 180/1120, Loss: 0.0285
# Epoch 7, Batch 190/1120, Loss: 0.0066
# Epoch 7, Batch 200/1120, Loss: 0.0070
# Epoch 7, Batch 210/1120, Loss: 0.4735
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 
# Epoch 7, Batch 770/1120, Loss: 0.0429
# Epoch 7, Batch 780/1120, Loss: 0.1896
# Epoch 7, Batch 790/1120, Loss: 0.0313
# Epoch 7, Batch 800/1120, Loss: 0.0604
# Epoch 7, Batch 810/1120, Loss: 0.0115
# Epoch 7, Batch 820/1120, Loss: 0.0480
# Epoch 7, Batch 830/1120, Loss: 0.0628
# Epoch 7, Batch 840/1120, Loss: 0.0645
# Epoch 7, Batch 850/1120, Loss: 0.0027
# Epoch 7, Batch 860/1120, Loss: 0.0105
# Epoch 7, Batch 870/1120, Loss: 0.1355
# Epoch 7, Batch 880/1120, Loss: 0.0074
# Epoch 7, Batch 890/1120, Loss: 0.0319
# Epoch 7, Batch 900/1120, Loss: 0.1803
# Epoch 7, Batch 910/1120, Loss: 0.0130
# Epoch 7, Batch 920/1120, Loss: 0.3041
# Epoch 7, Batch 930/1120, Loss: 0.0066
# Epoch 7, Batch 940/1120, Loss: 0.3698
# Epoch 7, Batch 950/1120, Loss: 0.0887
# Epoch 7, Batch 960/1120, Loss: 0.1843
# Epoch 7, Batch 970/1120, Loss: 0.0259
# Epoch 7, Batch 980/1120, Loss: 0.1259
# Epoch 7, Batch 990/1120, Loss: 0.0070
# Epoch 7, Batch 1000/1120, Loss: 0.2051
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 7, Batch 1010/1120, Loss: 0.0704
# Epoch 7, Batch 1020/1120, Loss: 0.0072
# Epoch 7, Batch 1030/1120, Loss: 0.0292
# Epoch 7, Batch 1040/1120, Loss: 0.0436
# Epoch 7, Batch 1050/1120, Loss: 0.0389
# Epoch 7, Batch 1060/1120, Loss: 0.0646
# Epoch 7, Batch 1070/1120, Loss: 0.0454
# Epoch 7, Batch 1080/1120, Loss: 0.0652
# Epoch 7, Batch 1090/1120, Loss: 0.4438
# Epoch 7, Batch 1100/1120, Loss: 0.0167
# Epoch 7, Batch 1110/1120, Loss: 0.0165
# Epoch 7, Batch 1120/1120, Loss: 0.0774
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 7/10, Train Loss: 0.0646, Train Acc: 0.9764, Valid Loss: 0.8036, Valid Acc: 0.7815
# Epoch 8, Batch 10/1120, Loss: 0.0798
# Epoch 8, Batch 20/1120, Loss: 0.0142
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 8, Batch 30/1120, Loss: 0.0078
# Epoch 8, Batch 40/1120, Loss: 0.0070
# Epoch 8, Batch 50/1120, Loss: 0.0378
# Epoch 8, Batch 60/1120, Loss: 0.0103
# Epoch 8, Batch 70/1120, Loss: 0.0351
# Epoch 8, Batch 80/1120, Loss: 0.0175
# Epoch 8, Batch 90/1120, Loss: 0.1320
# Epoch 8, Batch 100/1120, Loss: 0.0432
# Epoch 8, Batch 110/1120, Loss: 0.0115
# Epoch 8, Batch 120/1120, Loss: 0.1793
# Epoch 8, Batch 130/1120, Loss: 0.0604
# Epoch 8, Batch 140/1120, Loss: 0.0909
# Epoch 8, Batch 150/1120, Loss: 0.0068
# Epoch 8, Batch 160/1120, Loss: 0.0354
# Epoch 8, Batch 170/1120, Loss: 0.0051
# Epoch 8, Batch 740/1120, Loss: 0.0106
# Epoch 8, Batch 750/1120, Loss: 0.0306
# Epoch 8, Batch 760/1120, Loss: 0.0085
# Epoch 8, Batch 770/1120, Loss: 0.0089
# Epoch 8, Batch 780/1120, Loss: 0.0182
# Epoch 8, Batch 790/1120, Loss: 0.1759
# Epoch 8, Batch 800/1120, Loss: 0.0545
# Epoch 8, Batch 810/1120, Loss: 0.0111
# Epoch 8, Batch 820/1120, Loss: 0.0387
# Epoch 8, Batch 830/1120, Loss: 0.0182
# Epoch 8, Batch 840/1120, Loss: 0.1233
# Epoch 8, Batch 850/1120, Loss: 0.0425
# Epoch 8, Batch 860/1120, Loss: 0.2575
# Epoch 8, Batch 870/1120, Loss: 0.2372
# Epoch 8, Batch 880/1120, Loss: 0.0322
# Epoch 8, Batch 890/1120, Loss: 0.0248
# Epoch 8, Batch 900/1120, Loss: 0.0046
# Epoch 8, Batch 910/1120, Loss: 0.1836
# Epoch 8, Batch 920/1120, Loss: 0.0151
# Epoch 8, Batch 930/1120, Loss: 0.1372
# Epoch 8, Batch 940/1120, Loss: 0.1862
# Epoch 8, Batch 950/1120, Loss: 0.2040
# Epoch 8, Batch 960/1120, Loss: 0.0085
# Epoch 8, Batch 970/1120, Loss: 0.0165
# Epoch 8, Batch 980/1120, Loss: 0.0256
# Epoch 8, Batch 990/1120, Loss: 0.0043
# Epoch 8, Batch 1000/1120, Loss: 0.0495
# Epoch 8, Batch 1010/1120, Loss: 0.2344
# Epoch 8, Batch 1020/1120, Loss: 0.0975
# Epoch 8, Batch 1030/1120, Loss: 0.0200
# Epoch 8, Batch 1040/1120, Loss: 0.0081
# Epoch 8, Batch 1050/1120, Loss: 0.0051
# Epoch 8, Batch 1060/1120, Loss: 0.2454
# Epoch 8, Batch 1070/1120, Loss: 0.0344
# Epoch 8, Batch 1080/1120, Loss: 0.2281
# Epoch 8, Batch 1090/1120, Loss: 0.1639
# Epoch 8, Batch 1100/1120, Loss: 0.1063
# Epoch 8, Batch 1110/1120, Loss: 0.0135
# Epoch 8, Batch 1120/1120, Loss: 0.3293
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 8/10, Train Loss: 0.0548, Train Acc: 0.9802, Valid Loss: 0.8898, Valid Acc: 0.7797
# Epoch 9, Batch 10/1120, Loss: 0.0232
# Epoch 9, Batch 20/1120, Loss: 0.1635
# Epoch 9, Batch 30/1120, Loss: 0.0098
# Epoch 9, Batch 40/1120, Loss: 0.0120
# Epoch 9, Batch 50/1120, Loss: 0.0179
# Epoch 9, Batch 60/1120, Loss: 0.0042
# Epoch 9, Batch 70/1120, Loss: 0.0055
# Epoch 9, Batch 80/1120, Loss: 0.0896
# Epoch 9, Batch 90/1120, Loss: 0.0898
# Epoch 9, Batch 100/1120, Loss: 0.0240
# Epoch 9, Batch 110/1120, Loss: 0.0063
# Epoch 9, Batch 120/1120, Loss: 0.0346
# Epoch 9, Batch 130/1120, Loss: 0.0771
# Epoch 9, Batch 140/1120, Loss: 0.0056
# Epoch 9, Batch 150/1120, Loss: 0.0061
# Epoch 9, Batch 720/1120, Loss: 0.0033
# Epoch 9, Batch 730/1120, Loss: 0.0016
# Epoch 9, Batch 740/1120, Loss: 0.0368
# Epoch 9, Batch 750/1120, Loss: 0.0152
# Epoch 9, Batch 760/1120, Loss: 0.1028
# Epoch 9, Batch 770/1120, Loss: 0.0816
# Epoch 9, Batch 780/1120, Loss: 0.0679
# Epoch 9, Batch 790/1120, Loss: 0.0070
# Epoch 9, Batch 800/1120, Loss: 0.0043
# Epoch 9, Batch 810/1120, Loss: 0.0496
# Epoch 9, Batch 820/1120, Loss: 0.1740
# Epoch 9, Batch 830/1120, Loss: 0.0447
# Epoch 9, Batch 840/1120, Loss: 0.0072
# Epoch 9, Batch 850/1120, Loss: 0.0053
# Epoch 9, Batch 860/1120, Loss: 0.0021
# Epoch 9, Batch 870/1120, Loss: 0.0151
# Epoch 9, Batch 880/1120, Loss: 0.0082
# Epoch 9, Batch 890/1120, Loss: 0.2266
# Epoch 9, Batch 900/1120, Loss: 0.0129
# Epoch 9, Batch 910/1120, Loss: 0.0105
# Epoch 9, Batch 920/1120, Loss: 0.0060
# Epoch 9, Batch 930/1120, Loss: 0.0318
# Epoch 9, Batch 940/1120, Loss: 0.0449
# Epoch 9, Batch 950/1120, Loss: 0.0089
# Epoch 9, Batch 960/1120, Loss: 0.2664
# Epoch 9, Batch 970/1120, Loss: 0.0191
# Epoch 9, Batch 980/1120, Loss: 0.0021
# Epoch 9, Batch 990/1120, Loss: 0.0094
# Epoch 9, Batch 1000/1120, Loss: 0.3179
# Epoch 9, Batch 1010/1120, Loss: 0.0036
# Epoch 9, Batch 1020/1120, Loss: 0.0914
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 9, Batch 1030/1120, Loss: 0.0010
# Epoch 9, Batch 1040/1120, Loss: 0.0100
# Epoch 9, Batch 1050/1120, Loss: 0.0076
# Epoch 9, Batch 1060/1120, Loss: 0.0217
# Epoch 9, Batch 1070/1120, Loss: 0.0162
# Epoch 9, Batch 1080/1120, Loss: 0.2413
# Epoch 9, Batch 1090/1120, Loss: 0.0191
# Epoch 9, Batch 1100/1120, Loss: 0.1137
# Epoch 9, Batch 1110/1120, Loss: 0.0105
# Epoch 9, Batch 1120/1120, Loss: 0.0506
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 9/10, Train Loss: 0.0394, Train Acc: 0.9859, Valid Loss: 0.9137, Valid Acc: 0.7805
# Epoch 10, Batch 10/1120, Loss: 0.0142
# Epoch 10, Batch 20/1120, Loss: 0.0253
# Epoch 10, Batch 30/1120, Loss: 0.0151
# Epoch 10, Batch 40/1120, Loss: 0.0230
# Epoch 10, Batch 50/1120, Loss: 0.0070
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 10, Batch 60/1120, Loss: 0.0064
# Epoch 10, Batch 70/1120, Loss: 0.0071
# Epoch 10, Batch 80/1120, Loss: 0.0543
# Epoch 10, Batch 90/1120, Loss: 0.0020
# Epoch 10, Batch 100/1120, Loss: 0.0031
# Epoch 10, Batch 110/1120, Loss: 0.0117
# Epoch 10, Batch 120/1120, Loss: 0.0060
# Epoch 10, Batch 130/1120, Loss: 0.0157
# Epoch 10, Batch 140/1120, Loss: 0.0407
# Epoch 10, Batch 150/1120, Loss: 0.0055
# Epoch 10, Batch 160/1120, Loss: 0.0059
# Epoch 10, Batch 170/1120, Loss: 0.0048
# Epoch 10, Batch 180/1120, Loss: 0.0054
# Epoch 10, Batch 190/1120, Loss: 0.0047
# Epoch 10, Batch 200/1120, Loss: 0.0517
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 10, Batch 210/1120, Loss: 0.0076
# Epoch 10, Batch 220/1120, Loss: 0.0043
# Epoch 10, Batch 230/1120, Loss: 0.2835
# Epoch 10, Batch 240/1120, Loss: 0.0809
# Epoch 10, Batch 250/1120, Loss: 0.0278
# Epoch 10, Batch 260/1120, Loss: 0.0028
# Epoch 10, Batch 270/1120, Loss: 0.0020
# Epoch 10, Batch 280/1120, Loss: 0.0131
# Epoch 10, Batch 290/1120, Loss: 0.0161
# Epoch 10, Batch 300/1120, Loss: 0.0097
# Epoch 10, Batch 310/1120, Loss: 0.0096
# Epoch 10, Batch 320/1120, Loss: 0.0992
# Epoch 10, Batch 330/1120, Loss: 0.0052
# Epoch 10, Batch 340/1120, Loss: 0.0037
# Epoch 10, Batch 350/1120, Loss: 0.0015
# Epoch 10, Batch 360/1120, Loss: 0.0026
# Epoch 10, Batch 370/1120, Loss: 0.0014
# Epoch 10, Batch 380/1120, Loss: 0.0022
# Epoch 10, Batch 390/1120, Loss: 0.0012
# Epoch 10, Batch 400/1120, Loss: 0.0043
# Epoch 10, Batch 410/1120, Loss: 0.0048
# Epoch 10, Batch 420/1120, Loss: 0.0123
# Epoch 10, Batch 430/1120, Loss: 0.0071
# Epoch 10, Batch 440/1120, Loss: 0.0013
# Epoch 10, Batch 450/1120, Loss: 0.0022
# Epoch 10, Batch 460/1120, Loss: 0.0111
# Epoch 10, Batch 470/1120, Loss: 0.0033
# Epoch 10, Batch 480/1120, Loss: 0.0133
# Epoch 10, Batch 490/1120, Loss: 0.0033
# Epoch 10, Batch 500/1120, Loss: 0.0055
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# Epoch 10, Batch 510/1120, Loss: 0.0027
# Epoch 10, Batch 520/1120, Loss: 0.0160
# Epoch 10, Batch 530/1120, Loss: 0.0509
# Epoch 10, Batch 540/1120, Loss: 0.0154
# Epoch 10, Batch 550/1120, Loss: 0.2834
# Epoch 10, Batch 560/1120, Loss: 0.0205
# Epoch 10, Batch 570/1120, Loss: 0.0028
# Epoch 10, Batch 580/1120, Loss: 0.2058
# Epoch 10, Batch 590/1120, Loss: 0.0029
# Epoch 10, Batch 600/1120, Loss: 0.0449
# Epoch 10, Batch 610/1120, Loss: 0.0044
# Epoch 10, Batch 620/1120, Loss: 0.0074
# Epoch 10, Batch 630/1120, Loss: 0.0064
# Epoch 10, Batch 640/1120, Loss: 0.0054
# Epoch 10, Batch 650/1120, Loss: 0.0104
# Epoch 10, Batch 660/1120, Loss: 0.0083
# Epoch 10, Batch 670/1120, Loss: 0.0099
# Epoch 10, Batch 680/1120, Loss: 0.0652
# Epoch 10, Batch 690/1120, Loss: 0.0101
# Epoch 10, Batch 700/1120, Loss: 0.0022
# Epoch 10, Batch 710/1120, Loss: 0.0279
# Epoch 10, Batch 720/1120, Loss: 0.0210
# Epoch 10, Batch 730/1120, Loss: 0.0070
# Epoch 10, Batch 740/1120, Loss: 0.0022
# Epoch 10, Batch 750/1120, Loss: 0.0030
# Epoch 10, Batch 760/1120, Loss: 0.0039
# Epoch 10, Batch 770/1120, Loss: 0.0082
# Epoch 10, Batch 780/1120, Loss: 0.0570
# Epoch 10, Batch 790/1120, Loss: 0.0238
# Epoch 10, Batch 800/1120, Loss: 0.0074
# Epoch 10, Batch 810/1120, Loss: 0.0029
# Epoch 10, Batch 820/1120, Loss: 0.0029
# Epoch 10, Batch 830/1120, Loss: 0.0023
# Epoch 10, Batch 840/1120, Loss: 0.0013
# Epoch 10, Batch 850/1120, Loss: 0.0015
# Epoch 10, Batch 860/1120, Loss: 0.0067
# Epoch 10, Batch 870/1120, Loss: 0.0101
# Epoch 10, Batch 880/1120, Loss: 0.0005
# Epoch 10, Batch 890/1120, Loss: 0.0035
# Epoch 10, Batch 900/1120, Loss: 0.0573
# Epoch 10, Batch 910/1120, Loss: 0.0060
# Epoch 10, Batch 920/1120, Loss: 0.0355
# Epoch 10, Batch 930/1120, Loss: 0.0055
# Epoch 10, Batch 940/1120, Loss: 0.0012
# Epoch 10, Batch 950/1120, Loss: 0.0281
# Epoch 10, Batch 960/1120, Loss: 0.0236
# Epoch 10, Batch 970/1120, Loss: 0.0056
# Epoch 10, Batch 980/1120, Loss: 0.0022
# Epoch 10, Batch 990/1120, Loss: 0.0345
# Epoch 10, Batch 1000/1120, Loss: 0.0036
# Epoch 10, Batch 1010/1120, Loss: 0.0023
# Epoch 10, Batch 1020/1120, Loss: 0.0038
# Epoch 10, Batch 1030/1120, Loss: 0.0064
# Epoch 10, Batch 1040/1120, Loss: 0.0016
# Epoch 10, Batch 1050/1120, Loss: 0.0109
# Epoch 10, Batch 1060/1120, Loss: 0.0072
# Epoch 10, Batch 1070/1120, Loss: 0.0098
# Epoch 10, Batch 1080/1120, Loss: 0.0060
# Epoch 10, Batch 1090/1120, Loss: 0.0477
# Epoch 10, Batch 1100/1120, Loss: 0.0389
# Epoch 10, Batch 1110/1120, Loss: 0.0111
# Epoch 10, Batch 1120/1120, Loss: 0.0146
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Epoch 10/10, Train Loss: 0.0301, Train Acc: 0.9901, Valid Loss: 1.0162, Valid Acc: 0.7833
# /tmp/ipykernel_31/588673138.py:426: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load('best_resnet50_bert_model.pth'))
# Evaluating model on test set...
# /usr/local/lib/python3.11/dist-packages/PIL/TiffImagePlugin.py:949: UserWarning: Corrupt EXIF data.  Expecting to read 4 bytes but only got 0.
#   warnings.warn(str(msg))
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Test Accuracy: 0.7979
#
# Confusion Matrix:
# [[ 998  234]
#  [ 542 2066]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Harmful       0.65      0.81      0.72      1232
#      Harmful       0.90      0.79      0.84      2608
#
#     accuracy                           0.80      3840
#    macro avg       0.77      0.80      0.78      3840
# weighted avg       0.82      0.80      0.80      3840
# ResNet50 model training and evaluation complete!
